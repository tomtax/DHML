# %% [markdown]
# # Framework for predictions and portfolio forming

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import time

# import the parquet library
import pyarrow.parquet as pq

# import model libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
# load 'basemodel.parquet'
#df = pd.read_parquet('basemodel.parquet')
df = pd.read_parquet('/kaggle/input/sign-prediction-datasets/basicmarket.parquet')
prediction_cols = []
df.head()
# Out:
#    PERMNO       date       RET          ME  bull_D  bear_D  bull_W  bear_W  \
# 0   10000 1987-03-31 -0.384615   973.25000     0.0     0.0     0.0     1.0
# 1   10000 1987-04-30 -0.062500   912.44134     0.0     0.0     0.0     0.0
# 2   10000 1987-05-31 -0.066667   851.59375     0.0     0.0     0.0     0.0
# 3   10001 1987-03-31  0.036800  6317.62500     0.0     0.0     0.0     1.0
# 4   10001 1987-04-30 -0.039216  6069.87500     0.0     0.0     0.0     0.0
#
#    bull_M  bear_M    LMKT      IVOL  y       STR  LTURNOVER      IMOM  \
# 0       0       0  0.0482  0.000612  0  0.000000   0.100694 -1.089044
# 1       0       1  0.0211  0.003465  0 -0.384615   0.285384 -1.459321
# 2       0       2 -0.0167  0.001893  0 -0.062500   0.256358 -1.633155
# 3       0       0  0.0482  0.001627  1 -0.074074   0.368315  0.071156
# 4       0       0  0.0211  0.001597  0  0.036800   0.217962  0.043187
#
#         MOM       LTR   PCTHIGH     IVOL2     IVOL3      MVOL     MVOL2  \
# 0 -2.079441 -0.297252  0.091549  0.000830  0.002413  0.545027  0.771919
# 1 -2.390877  0.014185  0.062500  0.000612  0.000830  0.672597  0.545027
# 2 -2.772587 -0.089613  0.075378  0.003465  0.000612  1.565461  0.672597
# 3  0.140122  0.020203  0.892857  0.001556  0.001527  0.545027  0.771919
# 4  0.038273  0.045090  0.910714  0.001627  0.001556  0.672597  0.545027
#
#       MVOL3   LMKT2   LMKT3      MMOM     MIMOM      MLTR   LSPREAD
# 0  0.434190  0.1289 -0.0278  0.186212  0.112764  0.459110  0.076923
# 1  0.771919  0.0482  0.1289  0.179935 -0.025601  0.498953  0.625000
# 2  0.545027  0.0211  0.0482  0.208747  0.032263  0.488026  0.133330
# 3  0.434190  0.1289 -0.0278  0.186212  0.112764  0.459110  0.120000
# 4  0.771919  0.0482  0.1289  0.179935 -0.025601  0.498953  0.078431

# %%
# select the columns to be used for prediction
X_col = ['bull_D', 'bear_D', 'bull_W', 'bear_W', 'bull_M', 'bear_M', 'LMKT', 'IVOL', # initial columns
         'STR',	'LTURNOVER', 'IMOM', 'MOM',	'LTR', 'PCTHIGH', 'IVOL2', 'IVOL3', 'LSPREAD',	# stock specific columns
         'MVOL', 'MVOL2', 'MVOL3', 'LMKT2',	'LMKT3', 'MMOM', 'MIMOM', 'MLTR'] # market specific columns

# %%
# scale the data for faster coeficient convergence
scaler = MinMaxScaler()

df[X_col] = scaler.fit_transform(df[X_col])

# %%
# Convert 'date' to datetime format (if not already done) and sort the DataFrame
df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)
df.reset_index(drop=True, inplace=True)

# Create a 'year' column based on the 'date' column
df['year'] = df['date'].dt.year

# %% [markdown]
# # Paper Replication - OLS and Logit, Expanding Window - No Hyperparameters
# - They start with out of sample forecasting in 1932
# - models will be named model_default

# %% [markdown]
# ### Linear Regression (Pooled OLS)

# %%
#################################
# OLS, default, exp window
#################################

model_name = 'base_ols_default'


# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)
# 3076048  0.000034  0.000010  0.109743  0.128462  0.073585  0.423071  0.288758
# 3076049  0.000003  0.000004  0.109743  0.128462  0.073585  0.423071  0.288758
# 3076050  0.000130  0.000202  0.109743  0.128462  0.073585  0.423071  0.288758
# 3076051  0.000033  0.000061  0.109743  0.128462  0.073585  0.423071  0.288758
#
#              MMOM     MIMOM      MLTR   LSPREAD  year  base_ols_default  \
# 3076047  0.520342  0.538953  0.814156  0.009789  2022         -0.784252
# 3076048  0.520342  0.538953  0.814156  0.002150  2022          0.859305
# 3076049  0.520342  0.538953  0.814156  0.001340  2022          0.907330
# 3076050  0.520342  0.538953  0.814156  0.004310  2022          0.088415
# 3076051  0.520342  0.538953  0.814156  0.004467  2022          0.723794
#
#          ols_default
# 3076047    -0.838064
# 3076048     0.836580
# 3076049     0.869929
# 3076050     0.048938
# 3076051     0.825924

# %% [markdown]
# # My Experiments

# %% [markdown]
# ## Machine Learning - Hyperparameter Tuning included in the process
# - models to be named 'model_clas/reg_exp/roll'

# %% [markdown]
# ### First expanding, then rolling
# start predicting for 1932, expand the window until you reach X years, then roll it

# %% [markdown]
# #### MSE Evaluation

# %% [markdown]
# ##### 5 years

# %%
rolling_window = 5

# %%
############################################
# RIDGE CLASSIFICATION MODEL - MSE
############################################

model_name = 'ridge_clas_roll5_MSE'  # Name of the new column for storing predictions
start_time2 = time.time()  # Start timing


# Predefined set of C values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100] # C

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 6

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
       
    best_HP1 = None
    best_mse = np.inf
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = LogisticRegression(C=hp1, max_iter=1000, penalty='l2')  # Ridge
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    
    # Retrain on the entire training window (excluding tuning year) with the best C value
    model = LogisticRegression(C=best_HP1, max_iter=1000, penalty='l2')
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best C: {best_HP1}, Best ACC: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")


end_time2 = time.time()  # End timing
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1933 - Best C: 100, Best ACC: 0.0749, Time: 7.99 seconds
# Year 1934 - Best C: 100, Best ACC: 0.0505, Time: 7.68 seconds
# Year 1935 - Best C: 100, Best ACC: 0.0609, Time: 8.69 seconds
# Year 1936 - Best C: 100, Best ACC: 0.0709, Time: 9.38 seconds
# Year 1937 - Best C: 100, Best ACC: 0.0612, Time: 9.87 seconds
# Year 1938 - Best C: 100, Best ACC: 0.0532, Time: 8.12 seconds
# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

start_modeling_year = df['year'].min() + 6

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Timing each iteration
    
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = np.inf
    
    # Hyperparameter tuning for max_depth
    for hp1 in HP1:
        model = DecisionTreeClassifier(max_depth=hp1)
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training window with the best max_depth value
    model = DecisionTreeClassifier(max_depth=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict_proba(X_next_year)[:, 1]
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()
    iteration_time = end_time - start_time
    
    print(f"Year {year} - Best Max Depth: {best_HP1}, Best ACC: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")

end_time2 = time.time()  # End timing
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1933 - Best Max Depth: 5, Best ACC: 0.04, Time: 1.63 seconds
# Year 1934 - Best Max Depth: 5, Best ACC: 0.03, Time: 1.67 seconds
# Year 1935 - Best Max Depth: 5, Best ACC: 0.032, Time: 1.72 seconds
# Year 1936 - Best Max Depth: 5, Best ACC: 0.0294, Time: 1.83 seconds
# Year 1937 - Best Max Depth: 5, Best ACC: 0.0207, Time: 1.72 seconds
# Year 1938 - Best Max Depth: 5, Best ACC: 0.0196, Time: 1.66 seconds
# Year 1939 - Best Max Depth: 5, Best ACC: 0.0269, Time: 1.73 seconds
# Year 1940 - Best Max Depth: 5, Best ACC: 0.03, Time: 1.78 seconds
# Year 1941 - Best Max Depth: 5, Best ACC: 0.0388, Time: 1.94 seconds
# Year 1942 - Best Max Depth: 5, Best ACC: 0.038, Time: 1.98 seconds
# Year 1943 - Best Max Depth: 5, Best ACC: 0.0366, Time: 2.02 seconds
# Year 1944 - Best Max Depth: 5, Best ACC: 0.0236, Time: 2.01 seconds
# Year 1945 - Best Max Depth: 5, Best ACC: 0.0285, Time: 1.94 seconds
# Year 1946 - Best Max Depth: 5, Best ACC: 0.014, Time: 2.01 seconds
# Year 1947 - Best Max Depth: 5, Best ACC: 0.0168, Time: 1.88 seconds
# Year 1948 - Best Max Depth: 5, Best ACC: 0.0267, Time: 1.98 seconds
# Year 1949 - Best Max Depth: 5, Best ACC: 0.0236, Time: 2.01 seconds
# Year 1950 - Best Max Depth: 5, Best ACC: 0.0252, Time: 2.18 seconds
# Year 1951 - Best Max Depth: 5, Best ACC: 0.0212, Time: 2.30 seconds
# Year 1952 - Best Max Depth: 5, Best ACC: 0.0245, Time: 2.38 seconds
# Year 1953 - Best Max Depth: 5, Best ACC: 0.0322, Time: 2.45 seconds
# Year 1954 - Best Max Depth: 5, Best ACC: 0.0317, Time: 2.52 seconds
# Year 1955 - Best Max Depth: 5, Best ACC: 0.0197, Time: 2.63 seconds
# Year 1956 - Best Max Depth: 5, Best ACC: 0.0241, Time: 2.63 seconds
# Year 1957 - Best Max Depth: 5, Best ACC: 0.0262, Time: 2.64 seconds
# Year 1995 - Best Max Depth: 10, Best ACC: 0.0408, Time: 18.97 seconds
# Year 1996 - Best Max Depth: 10, Best ACC: 0.0346, Time: 19.16 seconds
# Year 1997 - Best Max Depth: 10, Best ACC: 0.0313, Time: 19.64 seconds
# Year 1998 - Best Max Depth: 10, Best ACC: 0.0247, Time: 20.57 seconds
# Year 1999 - Best Max Depth: 10, Best ACC: 0.0215, Time: 21.49 seconds
# Year 2000 - Best Max Depth: 10, Best ACC: 0.0204, Time: 21.78 seconds
# Year 2001 - Best Max Depth: 10, Best ACC: 0.0188, Time: 22.42 seconds
# Year 2002 - Best Max Depth: 5, Best ACC: 0.01, Time: 21.51 seconds
# Year 2003 - Best Max Depth: 5, Best ACC: 0.0075, Time: 20.48 seconds
# Year 2004 - Best Max Depth: 5, Best ACC: 0.0061, Time: 19.31 seconds
# Year 2005 - Best Max Depth: 5, Best ACC: 0.0054, Time: 17.20 seconds
# Year 2006 - Best Max Depth: 5, Best ACC: 0.005, Time: 16.15 seconds
# Year 2007 - Best Max Depth: 5, Best ACC: 0.0049, Time: 15.03 seconds
# Year 2008 - Best Max Depth: 5, Best ACC: 0.0049, Time: 14.30 seconds
# Year 2009 - Best Max Depth: 5, Best ACC: 0.0048, Time: 14.25 seconds
# Year 2010 - Best Max Depth: 5, Best ACC: 0.0048, Time: 14.28 seconds
# Year 2011 - Best Max Depth: 5, Best ACC: 0.0046, Time: 14.03 seconds
# Year 2012 - Best Max Depth: 5, Best ACC: 0.0042, Time: 13.18 seconds
# Year 2013 - Best Max Depth: 5, Best ACC: 0.0042, Time: 12.44 seconds
# Year 2014 - Best Max Depth: 5, Best ACC: 0.0036, Time: 11.84 seconds
# Year 2015 - Best Max Depth: 5, Best ACC: 0.0032, Time: 10.63 seconds
# Year 2016 - Best Max Depth: 5, Best ACC: 0.0035, Time: 11.17 seconds
# Year 2017 - Best Max Depth: 5, Best ACC: 0.0029, Time: 10.65 seconds
# Year 2018 - Best Max Depth: 5, Best ACC: 0.0058, Time: 10.54 seconds
# Year 2019 - Best Max Depth: 5, Best ACC: 0.0043, Time: 10.65 seconds
# Year 2020 - Best Max Depth: 5, Best ACC: 0.0026, Time: 10.33 seconds
# Year 2021 - Best Max Depth: 5, Best ACC: 0.0023, Time: 10.23 seconds
# Year 2022 - Best Max Depth: 5, Best ACC: 0.0024, Time: 10.23 seconds
# Total time: 785.18 seconds

# %%
############################################
# RF CLASSIFICATION MODEL - ACCURACY
############################################

model_name = 'RF_class_roll5_MSE'
start_time2 = time.time()


# Predefined set of values for hyperparameter tuning
HP1 = [10, 50, 100, 200]  # Possible values for n_estimators
HP2 = [5, 10, 15, None]  # Possible values for max_depth

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

start_modeling_year = df['year'].min() + 6

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Timing each iteration
    
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_HP2 = None
    best_mse = np.inf

    # Hyperparameter tuning
    for hp1 in HP1:
        for hp2 in HP2:
            model = RandomForestClassifier(n_estimators=hp1, max_depth=hp2, random_state=42, n_jobs=-1)
            model.fit(X_train, y_train)
            predictions = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
            mse = mean_squared_error(y_tune, predictions)  # Calculate MSE
            
            # Lower MSE is better, so we invert the logic used for accuracy
            if mse < best_mse:
                best_mse = mse
                best_HP1 = hp1
                best_HP2 = hp2
    
    # Retrain on the entire training window with the best max_depth value
    model = model = RandomForestClassifier(n_estimators=best_HP1, max_depth=best_HP2, random_state=42, n_jobs=-1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict_proba(X_next_year)[:, 1]
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()
    iteration_time = end_time - start_time
    
    print(f"Year {year} - Best n_estimators: {best_HP1}, Best max_depth: {best_HP2 if best_HP2 is not None else 'None'}, Best ACC: {round(best_mse, 2)}, Time: {iteration_time:.2f} seconds")

end_time2 = time.time()
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1933 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.05, Time: 33.53 seconds
# Year 1934 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 34.74 seconds
# Year 1935 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 36.42 seconds
# Year 1936 - Best n_estimators: 100, Best max_depth: None, Best ACC: 0.04, Time: 34.70 seconds
# Year 1937 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 36.62 seconds
# Year 1938 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 36.67 seconds
# Year 1939 - Best n_estimators: 100, Best max_depth: 15, Best ACC: 0.04, Time: 33.87 seconds
# Year 1940 - Best n_estimators: 50, Best max_depth: 15, Best ACC: 0.03, Time: 33.69 seconds
# Year 1941 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.04, Time: 39.12 seconds
# Year 1942 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 40.97 seconds
# Year 1943 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.04, Time: 41.84 seconds
# Year 1944 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 42.58 seconds
# Year 1945 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 40.59 seconds
# Year 1946 - Best n_estimators: 100, Best max_depth: None, Best ACC: 0.02, Time: 38.30 seconds
# Year 1947 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.02, Time: 40.76 seconds
# Year 1948 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 40.58 seconds
# Year 1949 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 41.21 seconds
# Year 1950 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 43.64 seconds
# Year 1951 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 46.77 seconds
# Year 1952 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 48.65 seconds
# Year 1953 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.04, Time: 49.96 seconds
# Year 1954 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 52.73 seconds
# Year 1955 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 53.73 seconds
# Year 1956 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 54.03 seconds
# Year 1957 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 55.06 seconds
# Year 1958 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 54.29 seconds
# Year 1959 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.02, Time: 54.59 seconds
# Year 1960 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 56.35 seconds
# Year 1961 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 52.61 seconds
# Year 1962 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.02, Time: 52.10 seconds
# Year 1963 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.02, Time: 52.03 seconds
# Year 1964 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 54.22 seconds
# Year 1965 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 63.02 seconds
# Year 1966 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 77.22 seconds
# Year 1967 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 93.85 seconds
# Year 1968 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.02, Time: 106.20 seconds
# Year 1969 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 114.54 seconds
# Year 1970 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 113.32 seconds
# Year 1971 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 113.90 seconds
# Year 1972 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 115.52 seconds
# Year 1973 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 116.04 seconds
# Year 1974 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 124.49 seconds
# Year 1975 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 131.59 seconds
# Year 1976 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 138.01 seconds
# Year 1977 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 145.69 seconds
# Year 1978 - Best n_estimators: 100, Best max_depth: 15, Best ACC: 0.03, Time: 134.22 seconds
# Year 1979 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 147.37 seconds
# Year 1980 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 141.28 seconds
# Year 1981 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 138.72 seconds
# Year 1982 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 133.67 seconds
# Year 1983 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 128.30 seconds
# Year 1984 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 130.00 seconds
# Year 1985 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 173.55 seconds
# Year 1986 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 223.37 seconds
# Year 1987 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 286.04 seconds
# Year 1988 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 350.74 seconds
# Year 1989 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.05, Time: 357.17 seconds
# Year 1990 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.05, Time: 372.29 seconds
# Year 1991 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.05, Time: 380.07 seconds
# Year 1992 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.05, Time: 392.14 seconds
# Year 1993 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 400.33 seconds
# Year 1994 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 385.49 seconds
# Year 1995 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 376.76 seconds
# Year 1996 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.04, Time: 390.72 seconds
# Year 1997 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.03, Time: 410.53 seconds
# Year 1998 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.03, Time: 427.22 seconds
# Year 1999 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 455.02 seconds
# Year 2000 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 462.48 seconds
# Year 2001 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.02, Time: 452.16 seconds
# Year 2002 - Best n_estimators: 200, Best max_depth: 15, Best ACC: 0.01, Time: 438.36 seconds
# Year 2003 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 436.16 seconds
# Year 2004 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 415.68 seconds
# Year 2005 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 382.53 seconds
# Year 2006 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 349.08 seconds
# Year 2007 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 322.37 seconds
# Year 2008 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 298.64 seconds
# Year 2009 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 298.16 seconds
# Year 2010 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 296.26 seconds
# Year 2011 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 286.47 seconds
# Year 2012 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 268.23 seconds
# Year 2013 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 251.36 seconds
# Year 2014 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 238.62 seconds
# Year 2015 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 230.38 seconds
# Year 2016 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 224.10 seconds
# Year 2017 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 220.87 seconds
# Year 2018 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 217.49 seconds
# Year 2019 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.01, Time: 221.58 seconds
# Year 2020 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 223.68 seconds
# Year 2021 - Best n_estimators: 100, Best max_depth: None, Best ACC: 0.0, Time: 196.88 seconds
# Year 2022 - Best n_estimators: 200, Best max_depth: None, Best ACC: 0.0, Time: 208.72 seconds
# Total time: 16155.63 seconds

# %% [markdown]
# ## Forming Portfolios, Value-weighted portfolio returns

# %%
df.head()
# Out:
#    PERMNO       date       RET         ME  bull_D    bear_D    bull_W  \
# 0   14314 1927-08-31 -0.164557    3902.25     0.0  0.000000  0.000000
# 1   12730 1927-08-31 -0.069853   88107.25     0.0  0.416667  0.000000
# 2   11594 1927-08-31  0.149390   14137.50     0.0  0.083333  0.000000
# 3   75471 1927-08-31  0.216216    1575.00     0.0  0.000000  0.000000
# 4   10786 1927-08-31  0.169811  111600.00     0.0  0.166667  0.583333
#
#      bear_W    bull_M  bear_M      LMKT      IVOL  y       STR  LTURNOVER  \
# 0  0.083333  0.000000     0.0  0.538722  0.000033  0  0.040267   0.000003
# 1  0.000000  0.000000     0.0  0.538722  0.000005  0  0.043893   0.000019
# 2  0.000000  0.250000     0.0  0.538722  0.000077  1  0.045470   0.000002
# 3  0.000000  0.083333     0.0  0.538722  0.000090  1  0.040866   0.000003
# 4  0.000000  0.083333     0.0  0.538722  0.000013  1  0.045594   0.000056
#
#        IMOM       MOM       LTR   PCTHIGH     IVOL2     IVOL3     MVOL  \
# 0  0.551246  0.668133  0.709597  0.443203  0.000036  0.000097  0.00106
# 1  0.611572  0.736577  0.697120  0.824047  0.000005  0.000004  0.00106
# 2  0.572206  0.709391  0.708355  0.869882  0.000005  0.000018  0.00106
# 3  0.570800  0.709576  0.684379  0.860310  0.000038  0.000123  0.00106
# 4  0.596852  0.722659  0.703022  1.000000  0.000003  0.000006  0.00106
#
#       MVOL2     MVOL3     LMKT2     LMKT3      MMOM     MIMOM      MLTR  \
# 0  0.008129  0.001942  0.397061  0.511976  0.645637  0.529397  0.644251
# 1  0.008129  0.001942  0.397061  0.511976  0.645637  0.529397  0.644251
# 2  0.008129  0.001942  0.397061  0.511976  0.645637  0.529397  0.644251
# 3  0.008129  0.001942  0.397061  0.511976  0.645637  0.529397  0.644251
# 4  0.008129  0.001942  0.397061  0.511976  0.645637  0.529397  0.644251
#
#     LSPREAD  year  base_ols_default  ols_default  ridge_clas_roll5_MSE  \
# 0  0.002245  1927               NaN          NaN                   NaN
# 1  0.001956  1927               NaN          NaN                   NaN
# 2  0.005677  1927               NaN          NaN                   NaN
# 3  0.003594  1927               NaN          NaN                   NaN
# 4  0.003555  1927               NaN          NaN                   NaN
#
#    DT_class_roll5_MSE  RF_class_roll5_MSE
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN

# %%
prediction_cols
# prediction_cols = ['logit_default','OLS_default','logit_roll6','DT_reg_roll']
# Out:
# ['base_ols_default',
#  'ols_default',
#  'ridge_clas_roll5_MSE',
#  'DT_class_roll5_MSE',
#  'RF_class_roll5_MSE']

# %%
portfolio = df[['date', 'RET', 'ME', 'y'] + prediction_cols].copy()
portfolio['date'] = pd.to_datetime(portfolio['date'])

# drop rows with missing values
portfolio.dropna(inplace=True)

portfolio.head()
# Out:
#             date       RET         ME  y  base_ols_default  ols_default  \
# 39215 1933-01-31  0.058824    456.750  1          0.275076     0.589930
# 39216 1933-01-31  0.427451  18036.000  1          0.756186     0.945905
# 39217 1933-01-31 -0.006993   1975.125  0          0.050649     0.231157
# 39218 1933-01-31  0.166667    241.500  1          0.704957     0.862059
# 39219 1933-01-31 -0.058824   3304.000  0         -0.222943    -0.008792
#
#        ridge_clas_roll5_MSE  DT_class_roll5_MSE  RF_class_roll5_MSE
# 39215          5.548031e-01            0.898343               0.630
# 39216          1.000000e+00            1.000000               0.910
# 39217          8.458596e-08            0.000000               0.035
# 39218          9.997302e-01            1.000000               0.895
# 39219          5.928324e-14            0.000000               0.030

# %%
portfolio.tail()
# Out:
#               date       RET            ME  y  base_ols_default  ols_default  \
# 3076047 2022-07-31 -0.203046  4.174787e+04  0         -0.784252    -0.838064
# 3076048 2022-07-31  0.135593  1.110135e+06  1          0.859305     0.836580
# 3076049 2022-07-31  0.074970  3.728386e+06  1          0.907330     0.869929
# 3076050 2022-07-31 -0.029348  1.304941e+05  0          0.088415     0.048938
# 3076051 2022-07-31  0.323765  9.311106e+08  1          0.723794     0.825924
#
#          ridge_clas_roll5_MSE  DT_class_roll5_MSE  RF_class_roll5_MSE
# 3076047          5.857704e-73            0.000000               0.050
# 3076048          9.690855e-01            0.992545               0.975
# 3076049          1.000000e+00            1.000000               0.985
# 3076050          1.302841e-22            0.000000               0.020
# 3076051          9.967314e-01            0.992545               0.960

# %%
# Initialize an empty DataFrame to store value-weighted returns for each model
vwreturns = pd.DataFrame(portfolio['date'].unique(), columns=['date'])  # Ensures all dates are included

for pred_col in prediction_cols:
    # Calculate deciles for this prediction
    decile_col = f'decile_{pred_col}'
    portfolio[decile_col] = portfolio.groupby(['date'])[pred_col].transform(lambda x: pd.qcut(x, 10, labels=False, duplicates='drop'))
    
    # Determine position based on deciles
    position_col = f'position_{pred_col}'
    portfolio[position_col] = np.where(portfolio[decile_col] == 9, 1, np.where(portfolio[decile_col] == 0, -1, 0))
    
    # Calculate the value-weighted return for this prediction
    vwret_col = f'vwreturn_{pred_col}'
    vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
    
    # Merge the temporary value-weighted returns with the main vwreturns DataFrame
    vwreturns = vwreturns.merge(vwreturns_temp, on='date', how='left')

# Ensure the 'date' column is the first column and is sorted
vwreturns = vwreturns.sort_values('date').reset_index(drop=True)
# Out:
# /tmp/ipykernel_18/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_18/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_18/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_18/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_18/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_base_ols_default  vwreturn_ols_default  \
# 0 1933-01-31                   0.020350              0.018723
# 1 1933-02-28                   0.010923              0.011374
# 2 1933-03-31                   0.028053              0.019686
# 3 1933-04-30                   0.075213              0.103667
# 4 1933-05-31                   0.024194              0.022140
#
#    vwreturn_ridge_clas_roll5_MSE  vwreturn_DT_class_roll5_MSE  \
# 0                       0.024002                     0.021885
# 1                       0.009797                     0.145270
# 2                       0.020832                     0.027125
# 3                       0.104251                    -0.000179
# 4                       0.022650                    -0.004281
#
#    vwreturn_RF_class_roll5_MSE
# 0                     0.023204
# 1                     0.009970
# 2                     0.026779
# 3                     0.011065
# 4                     0.010737

# %% [markdown]
# ### Compare to market data

# %%
#market = pd.read_csv('FF3_clean.csv')
market = pd.read_csv('/kaggle/input/sign-prediction-datasets/FF3_clean.csv')

# %%
market.head()
# Out:
#          date  Mkt-RF   SMB   HML    RF
# 0  1926-07-31    2.96 -2.56 -2.43  0.22
# 1  1926-08-31    2.64 -1.17  3.82  0.25
# 2  1926-09-30    0.36 -1.40  0.13  0.23
# 3  1926-10-31   -3.24 -0.09  0.70  0.32
# 4  1926-11-30    2.53 -0.10 -0.51  0.31

# %%
# create a new 'Mkt' which is a sum of Mkt-RF and RF
market['Mkt'] = market['Mkt-RF'] + market['RF']

# divide all columns by 100 except 'date'
market.iloc[:, 1:] = market.iloc[:, 1:] / 100

#set the 'date' column to datetime format
market['date'] = pd.to_datetime(market['date'])

# merge the market data (only date and Mkt columns) with the vwreturns DataFrame
vwreturns = vwreturns.merge(market[['date', 'Mkt']], on='date', how='left')

# transform all columns (except 'date') to a log: log(x+1) and save the result as lvwreturns
lvwreturns = vwreturns.copy()
lvwreturns.iloc[:, 1:] = np.log(vwreturns.iloc[:, 1:] + 1)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_base_ols_default  vwreturn_ols_default  \
# 0 1933-01-31                   0.020350              0.018723
# 1 1933-02-28                   0.010923              0.011374
# 2 1933-03-31                   0.028053              0.019686
# 3 1933-04-30                   0.075213              0.103667
# 4 1933-05-31                   0.024194              0.022140
#
#    vwreturn_ridge_clas_roll5_MSE  vwreturn_DT_class_roll5_MSE  \
# 0                       0.024002                     0.021885
# 1                       0.009797                     0.145270
# 2                       0.020832                     0.027125
# 3                       0.104251                    -0.000179
# 4                       0.022650                    -0.004281
#
#    vwreturn_RF_class_roll5_MSE     Mkt
# 0                     0.023204  0.0126
# 1                     0.009970 -0.1527
# 2                     0.026779  0.0333
# 3                     0.011065  0.3895
# 4                     0.010737  0.2147

# %%
lvwreturns.head()
# Out:
#         date  vwreturn_base_ols_default  vwreturn_ols_default  \
# 0 1933-01-31                   0.020146              0.018550
# 1 1933-02-28                   0.010864              0.011309
# 2 1933-03-31                   0.027667              0.019495
# 3 1933-04-30                   0.072519              0.098638
# 4 1933-05-31                   0.023906              0.021899
#
#    vwreturn_ridge_clas_roll5_MSE  vwreturn_DT_class_roll5_MSE  \
# 0                       0.023718                     0.021649
# 1                       0.009749                     0.135640
# 2                       0.020618                     0.026763
# 3                       0.099167                    -0.000179
# 4                       0.022398                    -0.004290
#
#    vwreturn_RF_class_roll5_MSE       Mkt
# 0                     0.022939  0.012521
# 1                     0.009921 -0.165700
# 2                     0.026427  0.032758
# 3                     0.011004  0.328944
# 4                     0.010680  0.194497

# %%
lvwreturns.describe()
# Out:
#                                 date  vwreturn_base_ols_default  \
# count                           1072                1072.000000
# mean   1977-11-17 20:54:37.611940288                   0.014942
# min              1933-01-31 00:00:00                  -0.011114
# 25%              1955-05-23 06:00:00                   0.009826
# 50%              1977-12-15 12:00:00                   0.013586
# 75%              2000-04-07 12:00:00                   0.018027
# max              2022-07-31 00:00:00                   0.078491
# std                              NaN                   0.007929
#
#        vwreturn_ols_default  vwreturn_ridge_clas_roll5_MSE  \
# count           1072.000000                    1072.000000
# mean               0.014632                       0.008362
# min               -0.046196                      -0.042875
# 25%                0.009861                       0.003199
# 50%                0.013339                       0.007465
# 75%                0.017580                       0.011767
# max                0.098638                       0.099167
# std                0.007952                       0.007029
#
#        vwreturn_DT_class_roll5_MSE  vwreturn_RF_class_roll5_MSE          Mkt
# count                  1072.000000                  1072.000000  1072.000000
# mean                      0.017494                     0.011965     0.009039
# min                      -0.212917                    -0.007160    -0.272203
# 25%                       0.003610                     0.006648    -0.017248
# 50%                       0.012380                     0.009968     0.013262
# 75%                       0.026507                     0.015334     0.038235
# max                       0.207777                     0.076129     0.328944
# std                       0.027592                     0.008354     0.048197

# %%
# save the lvwreturns and portfolio DataFrame to a parquet file into 'outputs' folder

# for reproducibility and visualization purposes
lvwreturns.to_parquet('market_lvwreturns_class1.parquet')
portfolio.to_parquet('market_portfolio_class1.parquet')

# save vwreturns DataFrame to a .dta file into 'outputs' folder
#vwreturns.to_stata('outputs/vwreturns.dta') # for backtasting in R - we need normal returns, not log returns
