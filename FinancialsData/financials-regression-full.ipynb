# %% [markdown]
# # Framework for predictions and portfolio forming

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import time

# import the parquet library
import pyarrow.parquet as pq

# import model libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
# load 'basemodel.parquet'
#df = pd.read_parquet('basemodel.parquet')
df= pd.read_parquet('/kaggle/input/sign-prediction-datasets/clean_financials.parquet')
#df= pd.read_parquet('clean_financials.parquet')
prediction_cols = []
df.head()
# Out:
#    PERMNO       date  y       RET         LME         ME  bull_D  bear_D  \
# 0   10000 1987-03-31  0 -0.384615  1581.53125  973.25000     0.0     0.0
# 1   10000 1987-04-30  0 -0.062500   973.25000  912.44134     0.0     0.0
# 2   10000 1987-05-31  0 -0.066667   912.44134  851.59375     0.0     0.0
# 3   10000 1987-06-30  0  0.000000   851.59375  851.59375     0.0     0.0
# 4   10005 1987-03-31  0  0.000000   795.11688  795.11688     0.0     0.0
#
#    bull_W  bear_W  bull_M  bear_M  SPREAD_L  LTURNOVER      IVOL     IVOL2  \
# 0     0.0     1.0       0       0  0.076923   0.100694  0.000612  0.000830
# 1     0.0     0.0       0       1  0.625000   0.285384  0.003465  0.000612
# 2     0.0     0.0       0       2  0.133330   0.256358  0.001893  0.003465
# 3     0.0     0.0       0       0  0.071451   0.209350  0.000190  0.001893
# 4     0.0     0.0       0       0  0.090936   0.016213  0.000532  0.021169
#
#       IVOL3       STR       LTR      IMOM       MOM   PCTHIGH      MVOL  \
# 0  0.002413  0.000000 -0.297252 -1.089044 -2.079441  0.091549  0.545027
# 1  0.000830 -0.384615  0.014185 -1.459321 -2.390877  0.062500  0.672597
# 2  0.000612 -0.062500 -0.089613 -1.633155 -2.772587  0.075378  1.565461
# 3  0.003465 -0.066667 -0.341485 -1.323014 -2.585254  0.070707  0.955605
# 4  0.000013  0.100000 -0.405465 -1.163152 -0.470004  0.578954  0.545027
#
#       MVOL2     MVOL3    LMKT   LMKT2   LMKT3      MMOM     MIMOM      MLTR  \
# 0  0.771919  0.434190  0.0482  0.1289 -0.0278  0.186212  0.112764  0.459110
# 1  0.545027  0.771919  0.0211  0.0482  0.1289  0.179935 -0.025601  0.498953
# 2  0.672597  0.545027 -0.0167  0.0211  0.0482  0.208747  0.032263  0.488026
# 3  1.565461  0.672597  0.0049 -0.0167  0.0211  0.142069 -0.002095  0.591159
# 4  0.771919  0.434190  0.0482  0.1289 -0.0278  0.186212  0.112764  0.459110
#
#    release_L    LAT   DPI2A_L     CTO_L     D2A_L     NOA_L      OL_L  \
# 0        0.0  2.115  0.000000  0.055319  0.037352  0.000000  0.236407
# 1        0.0  2.115  0.000000  0.055319  0.037352  0.000000  0.236407
# 2        1.0  2.115 -0.037825  0.074232  0.028309 -0.382033  0.293803
# 3        0.0  2.115 -0.037825  0.074232  0.028309 -0.382033  0.293803
# 4        0.0  1.954 -0.001485  0.023762  0.015865 -0.032673  0.044012
#
#       PCM_L    FC2Y_L   INVEST_L     RNA_L     S2E_L    PROF_L      PM_L  \
# 0 -1.495726  1.777778   0.000000  0.016564  0.279904  0.064593  0.230769
# 1 -1.495726  1.777778   0.000000  0.016564  0.279904  0.064593  0.230769
# 2 -1.101911  0.343949 -38.203310 -0.368640 -1.121429  2.535714 -2.261146
# 3 -1.101911  0.343949 -38.203310 -0.368640 -1.121429  2.535714 -2.261146
# 4  0.645833  1.437500  -3.267327 -0.423313  0.025263 -0.036316 -1.437500
#
#       ATO_L     ROA_L     FCF_L    A2ME_L    B2ME_L     S2P_L     ROE_L  \
# 0  0.071779 -0.061939 -0.024586  0.001067  0.000211  0.000059 -0.000083
# 1  0.071779 -0.061939 -0.024586  0.001067  0.000211  0.000059 -0.000135
# 2  0.163032 -0.108274 -0.146901  0.000660 -0.000071  0.000079 -0.000251
# 3  0.163032 -0.108274 -0.146901  0.000660 -0.000071  0.000079 -0.000269
# 4  0.294479 -0.033168 -0.018424  0.004506  0.004381  0.000111 -0.000084
#
#       LEV_L        TQ_L
# 0  0.000037  748.571277
# 1  0.000060  460.967849
# 2  0.000018  699.225968
# 3  0.000019  652.670811
# 4  0.000047  406.945179

# %%
# select the columns to be used for prediction
X_col = ['bull_D', 'bear_D', 'bull_W', 'bear_W', 'bull_M', 'bear_M', 'LMKT', 'IVOL', # initial columns
         'STR',	'LTURNOVER', 'IMOM', 'MOM',	'LTR', 'PCTHIGH', 'IVOL2', 'IVOL3', 'SPREAD_L',	# stock specific columns
         'MVOL', 'MVOL2', 'MVOL3', 'LMKT2',	'LMKT3', 'MMOM', 'MIMOM', 'MLTR', # market specific columns
         'LAT',	'DPI2A_L',	'CTO_L', 'D2A_L', 'NOA_L', 'OL_L',	'PCM_L', 'FC2Y_L',	
         'INVEST_L', 'RNA_L', 'S2E_L', 'PROF_L', 'PM_L', 'ATO_L', 'ROA_L', 	
         'FCF_L', 'A2ME_L',	'B2ME_L', 'S2P_L', 'ROE_L',	'LEV_L', 'TQ_L']

# %%
# scale the data for faster coeficient convergence
scaler = MinMaxScaler()

df[X_col] = scaler.fit_transform(df[X_col])

# %%
# Convert 'date' to datetime format (if not already done) and sort the DataFrame
df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)
df.reset_index(drop=True, inplace=True)

# Create a 'year' column based on the 'date' column
df['year'] = df['date'].dt.year

# %% [markdown]
# # Paper Replication - OLS and Logit, Expanding Window - No Hyperparameters
# - They start with out of sample forecasting in 1932
# - models will be named model_default

# %% [markdown]
# ### Linear Regression (Pooled OLS)

# %%
#################################
# OLS, default, exp window
#################################

model_name = 'ols_default'


# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

for year in range(df['year'].min() + 6, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Define the training data up until this year
    train_data = df[df['year'] < year]
    
    X_train = train_data[X_col]
    y_train = train_data['y']
    
    # Train the Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Time: {iteration_time:.2f} seconds")
# Out:
# Year 1976 - Time: 0.25 seconds
# Year 1977 - Time: 0.37 seconds
# Year 1978 - Time: 0.42 seconds
# Year 1979 - Time: 0.49 seconds
# Year 1980 - Time: 0.52 seconds
# Year 1981 - Time: 0.57 seconds
# Year 1982 - Time: 0.63 seconds
# Year 1983 - Time: 0.71 seconds
# Year 1984 - Time: 0.79 seconds
# Year 1985 - Time: 0.95 seconds
# Year 1986 - Time: 1.08 seconds
# Year 1987 - Time: 1.20 seconds
# Year 1988 - Time: 1.59 seconds
# Year 1989 - Time: 1.73 seconds
# Year 1990 - Time: 1.90 seconds
# Year 1991 - Time: 2.05 seconds
# Year 1992 - Time: 2.22 seconds
# Year 1993 - Time: 2.37 seconds
# Year 1994 - Time: 2.53 seconds
# Year 1995 - Time: 3.15 seconds
# Year 1996 - Time: 2.86 seconds
# Year 1997 - Time: 3.13 seconds
# Year 1998 - Time: 3.30 seconds
# Year 1999 - Time: 3.47 seconds
# Year 2000 - Time: 3.71 seconds
# Year 2001 - Time: 3.91 seconds
# Year 2002 - Time: 4.07 seconds
# Year 2003 - Time: 4.36 seconds
# Year 2004 - Time: 4.45 seconds
# Year 2005 - Time: 4.47 seconds
# Year 2006 - Time: 4.69 seconds
# Year 2007 - Time: 4.75 seconds
# Year 2008 - Time: 5.04 seconds
# Year 2009 - Time: 5.15 seconds
# Year 2010 - Time: 5.49 seconds
# Year 2011 - Time: 5.46 seconds
# Year 2012 - Time: 5.57 seconds
# Year 2013 - Time: 5.70 seconds
# Year 2014 - Time: 5.62 seconds
# Year 2015 - Time: 5.90 seconds
# Year 2016 - Time: 6.02 seconds
# Year 2017 - Time: 6.04 seconds
# Year 2018 - Time: 6.26 seconds
# Year 2019 - Time: 6.33 seconds
# Year 2020 - Time: 6.35 seconds
# Year 2021 - Time: 6.55 seconds
# Year 2022 - Time: 6.39 seconds

# %% [markdown]
# # My Experiments

# %% [markdown]
# ## Machine Learning - Hyperparameter Tuning included in the process
# - models to be named 'model_clas/reg_exp/roll'

# %% [markdown]
# ### First expanding, then rolling
# start predicting for 1932, expand the window until you reach X years, then roll it

# %% [markdown]
# ##### 5 year window

# %%
# set the length of the rolling window
rolling_window = 5 # years

# %%
#################################
# RIDGE REGRESSION
#################################


model_name = 'ridge_reg_roll5'  # Name for storing Ridge regression predictions
start_time2 = time.time()  # Start timing


# Predefined set of alpha values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100]  # Alpha for Ridge

# Update the column name for storing Ridge regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 6


for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Prepare training and tuning datasets
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_accuracy = 0  # Initialize with 0 for accuracy comparison
    
    # Hyperparameter tuning with accuracy on top and bottom deciles
    for hp1 in HP1:
        model = Ridge(alpha=hp1)
        model.fit(X_train, y_train)
        predictions = model.predict(X_tune)
        
        # Identify top and bottom deciles
        decile_thresholds = np.percentile(predictions, [10, 90])
        top_bottom_decile_mask = (predictions <= decile_thresholds[0]) | (predictions >= decile_thresholds[1])
        
        # Filter tuning dataset based on deciles
        filtered_y_tune = y_tune[top_bottom_decile_mask]
        filtered_predictions = predictions[top_bottom_decile_mask]
        
        # Assuming binary classification, convert continuous predictions to binary
        # This conversion logic might need adjustment based on your specific use case
        binary_predictions = (filtered_predictions >= 0.5).astype(int)
        
        # Calculate accuracy for filtered predictions
        decile_accuracy = accuracy_score(filtered_y_tune, binary_predictions)
        
        if decile_accuracy > best_accuracy:
            best_accuracy = decile_accuracy
            best_HP1 = hp1
    
    # Retrain with best hyperparameters on the entire training data
    model = Ridge(alpha=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year and update df
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best Alpha: {best_HP1}, Best Decile Accuracy: {round(best_accuracy, 4)}, Time: {iteration_time:.2f} seconds")

end_time2 = time.time()  # End timing
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1976 - Best Alpha: 0.1, Best Decile Accuracy: 0.9705, Time: 0.45 seconds
# Year 1977 - Best Alpha: 100, Best Decile Accuracy: 0.9985, Time: 0.62 seconds
# Year 1978 - Best Alpha: 1, Best Decile Accuracy: 0.9985, Time: 0.67 seconds
# Year 1979 - Best Alpha: 10, Best Decile Accuracy: 0.998, Time: 0.68 seconds
# Year 1980 - Best Alpha: 10, Best Decile Accuracy: 0.9977, Time: 0.71 seconds
# Year 1981 - Best Alpha: 1, Best Decile Accuracy: 0.9974, Time: 0.67 seconds
# Year 1982 - Best Alpha: 100, Best Decile Accuracy: 0.9956, Time: 0.67 seconds
# Year 1983 - Best Alpha: 10, Best Decile Accuracy: 0.9946, Time: 0.66 seconds
# Year 1984 - Best Alpha: 10, Best Decile Accuracy: 0.9973, Time: 0.69 seconds
# Year 1985 - Best Alpha: 100, Best Decile Accuracy: 0.9928, Time: 0.77 seconds
# Year 1986 - Best Alpha: 10, Best Decile Accuracy: 0.9968, Time: 0.82 seconds
# Year 1987 - Best Alpha: 10, Best Decile Accuracy: 0.9973, Time: 0.94 seconds
# Year 1988 - Best Alpha: 100, Best Decile Accuracy: 0.9912, Time: 1.03 seconds
# Year 1989 - Best Alpha: 100, Best Decile Accuracy: 0.9941, Time: 1.06 seconds
# Year 1990 - Best Alpha: 10, Best Decile Accuracy: 0.9962, Time: 1.12 seconds
# Year 1991 - Best Alpha: 100, Best Decile Accuracy: 0.9935, Time: 1.17 seconds
# Year 1992 - Best Alpha: 100, Best Decile Accuracy: 0.9962, Time: 1.13 seconds
# Year 1993 - Best Alpha: 100, Best Decile Accuracy: 0.9956, Time: 1.14 seconds
# Year 1994 - Best Alpha: 100, Best Decile Accuracy: 0.9969, Time: 1.13 seconds
# Year 1995 - Best Alpha: 1, Best Decile Accuracy: 0.994, Time: 1.19 seconds
# Year 1996 - Best Alpha: 10, Best Decile Accuracy: 0.9972, Time: 1.18 seconds
# Year 1997 - Best Alpha: 100, Best Decile Accuracy: 0.9977, Time: 1.19 seconds
# Year 1998 - Best Alpha: 10, Best Decile Accuracy: 0.9973, Time: 1.23 seconds
# Year 1999 - Best Alpha: 10, Best Decile Accuracy: 0.9959, Time: 1.32 seconds
# Year 2000 - Best Alpha: 100, Best Decile Accuracy: 0.9971, Time: 1.28 seconds
# Year 2001 - Best Alpha: 100, Best Decile Accuracy: 0.9975, Time: 1.27 seconds
# Year 2002 - Best Alpha: 100, Best Decile Accuracy: 0.9972, Time: 1.26 seconds
# Year 2003 - Best Alpha: 10, Best Decile Accuracy: 0.9975, Time: 1.25 seconds
# Year 2004 - Best Alpha: 10, Best Decile Accuracy: 0.9978, Time: 1.19 seconds
# Year 2005 - Best Alpha: 1, Best Decile Accuracy: 0.9986, Time: 1.16 seconds
# Year 2006 - Best Alpha: 10, Best Decile Accuracy: 0.9986, Time: 1.12 seconds
# Year 2007 - Best Alpha: 1, Best Decile Accuracy: 0.9977, Time: 1.10 seconds
# Year 2008 - Best Alpha: 1, Best Decile Accuracy: 0.9991, Time: 1.06 seconds
# Year 2009 - Best Alpha: 100, Best Decile Accuracy: 0.95, Time: 1.01 seconds
# Year 2010 - Best Alpha: 100, Best Decile Accuracy: 0.989, Time: 1.01 seconds
# Year 2011 - Best Alpha: 10, Best Decile Accuracy: 0.9966, Time: 0.99 seconds
# Year 2012 - Best Alpha: 10, Best Decile Accuracy: 0.9989, Time: 0.96 seconds
# Year 2013 - Best Alpha: 10, Best Decile Accuracy: 0.9983, Time: 0.94 seconds
# Year 2014 - Best Alpha: 1, Best Decile Accuracy: 0.9954, Time: 0.92 seconds
# Year 2015 - Best Alpha: 10, Best Decile Accuracy: 0.9992, Time: 0.90 seconds
# Year 2016 - Best Alpha: 1, Best Decile Accuracy: 0.9949, Time: 0.86 seconds
# Year 2017 - Best Alpha: 100, Best Decile Accuracy: 0.9972, Time: 0.87 seconds
# Year 2018 - Best Alpha: 10, Best Decile Accuracy: 0.9983, Time: 0.84 seconds
# Year 2019 - Best Alpha: 100, Best Decile Accuracy: 0.9965, Time: 0.85 seconds
# Year 2020 - Best Alpha: 100, Best Decile Accuracy: 0.9982, Time: 0.82 seconds
# Year 2021 - Best Alpha: 100, Best Decile Accuracy: 0.9959, Time: 0.82 seconds
# Year 2022 - Best Alpha: 100, Best Decile Accuracy: 0.9983, Time: 0.82 seconds
# Total time: 45.60 seconds

# %%
#################################
# LASSO REGRESSION
#################################


model_name = 'lasso_reg_roll5'  # Name for storing Ridge regression predictions
start_time2 = time.time()  # Start timing


# Predefined set of alpha values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100]  # Alpha for Ridge

# Update the column name for storing Ridge regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 6


for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Prepare training and tuning datasets
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_accuracy = 0  # Initialize with 0 for accuracy comparison
    
    # Hyperparameter tuning with accuracy on top and bottom deciles
    for hp1 in HP1:
        model = Lasso(alpha=hp1)
        model.fit(X_train, y_train)
        predictions = model.predict(X_tune)
        
        # Identify top and bottom deciles
        decile_thresholds = np.percentile(predictions, [10, 90])
        top_bottom_decile_mask = (predictions <= decile_thresholds[0]) | (predictions >= decile_thresholds[1])
        
        # Filter tuning dataset based on deciles
        filtered_y_tune = y_tune[top_bottom_decile_mask]
        filtered_predictions = predictions[top_bottom_decile_mask]
        
        # Assuming binary classification, convert continuous predictions to binary
        # This conversion logic might need adjustment based on your specific use case
        binary_predictions = (filtered_predictions >= 0.5).astype(int)
        
        # Calculate accuracy for filtered predictions
        decile_accuracy = accuracy_score(filtered_y_tune, binary_predictions)
        
        if decile_accuracy > best_accuracy:
            best_accuracy = decile_accuracy
            best_HP1 = hp1
    
    # Retrain with best hyperparameters on the entire training data
    model = Lasso(alpha=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year and update df
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best Alpha: {best_HP1}, Best Decile Accuracy: {round(best_accuracy, 4)}, Time: {iteration_time:.2f} seconds")

end_time2 = time.time()  # End timing
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1976 - Best Alpha: 0.01, Best Decile Accuracy: 0.5396, Time: 0.42 seconds
# Year 1977 - Best Alpha: 0.01, Best Decile Accuracy: 0.9996, Time: 0.75 seconds
# Year 1978 - Best Alpha: 0.01, Best Decile Accuracy: 0.9988, Time: 0.97 seconds
# Year 1979 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 0.79 seconds
# Year 1980 - Best Alpha: 0.01, Best Decile Accuracy: 0.9966, Time: 0.71 seconds
# Year 1981 - Best Alpha: 0.01, Best Decile Accuracy: 0.9851, Time: 0.74 seconds
# Year 1982 - Best Alpha: 0.01, Best Decile Accuracy: 0.9703, Time: 0.83 seconds
# Year 1983 - Best Alpha: 0.01, Best Decile Accuracy: 0.9844, Time: 0.89 seconds
# Year 1984 - Best Alpha: 0.01, Best Decile Accuracy: 0.9959, Time: 0.84 seconds
# Year 1985 - Best Alpha: 0.01, Best Decile Accuracy: 0.9987, Time: 1.02 seconds
# Year 1986 - Best Alpha: 0.01, Best Decile Accuracy: 0.9995, Time: 1.21 seconds
# Year 1987 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.01 seconds
# Year 1988 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.11 seconds
# Year 1989 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 1.19 seconds
# Year 1990 - Best Alpha: 0.01, Best Decile Accuracy: 0.9999, Time: 1.11 seconds
# Year 1991 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.21 seconds
# Year 1992 - Best Alpha: 0.01, Best Decile Accuracy: 0.9991, Time: 1.25 seconds
# Year 1993 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.29 seconds
# Year 1994 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.19 seconds
# Year 1995 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.28 seconds
# Year 1996 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.20 seconds
# Year 1997 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.28 seconds
# Year 1998 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.41 seconds
# Year 1999 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.39 seconds
# Year 2000 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 1.35 seconds
# Year 2001 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.55 seconds
# Year 2002 - Best Alpha: 0.01, Best Decile Accuracy: 0.9996, Time: 1.35 seconds
# Year 2003 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 1.31 seconds
# Year 2004 - Best Alpha: 0.01, Best Decile Accuracy: 0.9992, Time: 1.29 seconds
# Year 2005 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 1.25 seconds
# Year 2006 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.18 seconds
# Year 2007 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.14 seconds
# Year 2008 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.12 seconds
# Year 2009 - Best Alpha: 0.01, Best Decile Accuracy: 0.9999, Time: 1.19 seconds
# Year 2010 - Best Alpha: 0.01, Best Decile Accuracy: 0.999, Time: 1.13 seconds
# Year 2011 - Best Alpha: 0.01, Best Decile Accuracy: 0.9994, Time: 1.39 seconds
# Year 2012 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.27 seconds
# Year 2013 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.04 seconds
# Year 2014 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.04 seconds
# Year 2015 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.08 seconds
# Year 2016 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 0.92 seconds
# Year 2017 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 0.94 seconds
# Year 2018 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.05 seconds
# Year 2019 - Best Alpha: 0.01, Best Decile Accuracy: 0.9998, Time: 0.99 seconds
# Year 2020 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 1.04 seconds
# Year 2021 - Best Alpha: 0.01, Best Decile Accuracy: 0.9995, Time: 0.87 seconds
# Year 2022 - Best Alpha: 0.01, Best Decile Accuracy: 1.0, Time: 0.94 seconds
# Total time: 51.56 seconds

# %%
#################################
# DECISION TREE REGRESSION
#################################

model_name = 'DT_reg_roll5'  # Name for storing Decision Tree regression predictions

# Predefined set of values for hyperparameter tuning (max_depth in this case)
HP1 = [None, 5, 10, 15, 20, 25]  # Possible values for max_depth

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 6


for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_accuracy = -1  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = DecisionTreeRegressor(max_depth=hp1)  # Decision Tree Regressor
        model.fit(X_train, y_train)
        predictions = model.predict(X_tune)
        
        # Identify top and bottom deciles
        decile_thresholds = np.percentile(predictions, [10, 90])
        top_bottom_decile_mask = (predictions <= decile_thresholds[0]) | (predictions >= decile_thresholds[1])
        
        # Filter tuning dataset based on deciles
        filtered_y_tune = y_tune[top_bottom_decile_mask]
        filtered_predictions = predictions[top_bottom_decile_mask]
        
        # Assuming binary classification, convert continuous predictions to binary
        # This conversion logic might need adjustment based on your specific use case
        binary_predictions = (filtered_predictions >= 0.5).astype(int)
        
        # Calculate accuracy for filtered predictions
        decile_accuracy = accuracy_score(filtered_y_tune, binary_predictions)
        
        if decile_accuracy > best_accuracy:
            best_accuracy = decile_accuracy
            best_HP1 = hp1
    
    # Retrain on the entire training window (excluding tuning year) with the best max_depth value
    model = DecisionTreeRegressor(max_depth=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)  # Predict continuous values
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best max_depth: {best_HP1}, Best ACC: {round(best_accuracy,4)}, Time: {iteration_time:.2f} seconds")
# Out:
# Year 1976 - Best max_depth: 5, Best ACC: 1.0, Time: 6.07 seconds
# Year 1977 - Best max_depth: 5, Best ACC: 1.0, Time: 9.12 seconds
# Year 1978 - Best max_depth: 5, Best ACC: 1.0, Time: 10.51 seconds
# Year 1979 - Best max_depth: 5, Best ACC: 1.0, Time: 10.80 seconds
# Year 1980 - Best max_depth: 5, Best ACC: 1.0, Time: 10.85 seconds
# Year 1981 - Best max_depth: 5, Best ACC: 1.0, Time: 10.91 seconds
# Year 1982 - Best max_depth: 5, Best ACC: 1.0, Time: 10.36 seconds
# Year 1983 - Best max_depth: 5, Best ACC: 1.0, Time: 10.34 seconds
# Year 1984 - Best max_depth: 5, Best ACC: 1.0, Time: 9.75 seconds
# Year 1985 - Best max_depth: 5, Best ACC: 1.0, Time: 11.45 seconds
# Year 1986 - Best max_depth: 5, Best ACC: 1.0, Time: 14.37 seconds
# Year 1987 - Best max_depth: 5, Best ACC: 1.0, Time: 16.84 seconds
# Year 1988 - Best max_depth: 5, Best ACC: 1.0, Time: 19.90 seconds
# Year 1989 - Best max_depth: 5, Best ACC: 1.0, Time: 20.75 seconds
# Year 1990 - Best max_depth: 5, Best ACC: 1.0, Time: 21.40 seconds
# Year 1991 - Best max_depth: 5, Best ACC: 1.0, Time: 22.39 seconds
# Year 1992 - Best max_depth: 5, Best ACC: 1.0, Time: 23.00 seconds
# Year 1993 - Best max_depth: 5, Best ACC: 1.0, Time: 23.19 seconds
# Year 1994 - Best max_depth: 5, Best ACC: 1.0, Time: 23.00 seconds
# Year 1995 - Best max_depth: 5, Best ACC: 1.0, Time: 23.21 seconds
# Year 1996 - Best max_depth: 5, Best ACC: 1.0, Time: 23.33 seconds
# Year 1997 - Best max_depth: 5, Best ACC: 1.0, Time: 24.26 seconds
# Year 1998 - Best max_depth: 5, Best ACC: 1.0, Time: 25.19 seconds
# Year 1999 - Best max_depth: 5, Best ACC: 1.0, Time: 26.27 seconds
# Year 2000 - Best max_depth: 5, Best ACC: 1.0, Time: 26.93 seconds
# Year 2001 - Best max_depth: 5, Best ACC: 1.0, Time: 27.27 seconds
# Year 2002 - Best max_depth: 5, Best ACC: 1.0, Time: 28.14 seconds
# Year 2003 - Best max_depth: 5, Best ACC: 1.0, Time: 26.70 seconds
# Year 2004 - Best max_depth: 5, Best ACC: 1.0, Time: 25.39 seconds
# Year 2005 - Best max_depth: 5, Best ACC: 1.0, Time: 23.89 seconds
# Year 2006 - Best max_depth: 5, Best ACC: 1.0, Time: 22.40 seconds
# Year 2007 - Best max_depth: 5, Best ACC: 1.0, Time: 20.11 seconds
# Year 2008 - Best max_depth: 5, Best ACC: 1.0, Time: 19.38 seconds
# Year 2009 - Best max_depth: 5, Best ACC: 1.0, Time: 19.30 seconds
# Year 2010 - Best max_depth: 5, Best ACC: 1.0, Time: 20.00 seconds
# Year 2011 - Best max_depth: 5, Best ACC: 1.0, Time: 19.35 seconds
# Year 2012 - Best max_depth: 5, Best ACC: 1.0, Time: 18.53 seconds
# Year 2013 - Best max_depth: 5, Best ACC: 1.0, Time: 18.25 seconds
# Year 2014 - Best max_depth: 5, Best ACC: 1.0, Time: 15.31 seconds
# Year 2015 - Best max_depth: 5, Best ACC: 1.0, Time: 14.88 seconds
# Year 2016 - Best max_depth: 5, Best ACC: 1.0, Time: 13.97 seconds
# Year 2017 - Best max_depth: 5, Best ACC: 1.0, Time: 14.53 seconds
# Year 2018 - Best max_depth: 5, Best ACC: 1.0, Time: 14.37 seconds
# Year 2019 - Best max_depth: 5, Best ACC: 1.0, Time: 14.51 seconds
# Year 2020 - Best max_depth: 5, Best ACC: 1.0, Time: 13.22 seconds
# Year 2021 - Best max_depth: 5, Best ACC: 1.0, Time: 13.50 seconds
# Year 2022 - Best max_depth: 5, Best ACC: 1.0, Time: 13.45 seconds

# %%
#################################
# RANDOM FOREST REGRESSION
#################################
start_time2 = time.time()  # Start timing

model_name = 'RF_reg_roll5'  # Name for storing Random Forest regression predictions

# Predefined set of values for hyperparameter tuning
HP1 = [10, 50, 100, 200]  # Possible values for n_estimators
HP2 = [5, 10, 15, None]  # Possible values for max_depth

# Update the column name for storing Random Forest regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 6


for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_HP2 = None
    best_accuracy = -1
    
    # Hyperparameter tuning
    for hp1 in HP1:
        for hp2 in HP2:
            model = RandomForestRegressor(n_estimators=hp1, max_depth=hp2, random_state=42, n_jobs = -1)
            model.fit(X_train, y_train)
            predictions = model.predict(X_tune)  # Predict continuous values
            
            # Identify top and bottom deciles
            decile_thresholds = np.percentile(predictions, [10, 90])
            top_bottom_decile_mask = (predictions <= decile_thresholds[0]) | (predictions >= decile_thresholds[1])

            # Filter tuning dataset based on deciles
            filtered_y_tune = y_tune[top_bottom_decile_mask]
            filtered_predictions = predictions[top_bottom_decile_mask]

            # Assuming binary classification, convert continuous predictions to binary
            # This conversion logic might need adjustment based on your specific use case
            binary_predictions = (filtered_predictions >= 0.5).astype(int)

            # Calculate accuracy for filtered predictions
            decile_accuracy = accuracy_score(filtered_y_tune, binary_predictions)

            if decile_accuracy > best_accuracy:
                best_accuracy = decile_accuracy
                best_HP1 = hp1
                best_HP2 = hp2
    
    # Retrain on the entire training window (excluding tuning year) with the best hyperparameters
    model = RandomForestRegressor(n_estimators=best_HP1, max_depth=best_HP2, random_state=42, n_jobs = -1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)  # Predict continuous values
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best n_estimators: {best_HP1}, Best max_depth: {best_HP2}, Best ACC: {round(best_accuracy,2)}, Time: {iteration_time:.2f} seconds")

end_time2 = time.time()
print(f"Total time: {end_time2 - start_time2:.2f} seconds")
# Out:
# Year 1976 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 286.59 seconds
# Year 1977 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 428.33 seconds
# Year 1978 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 490.24 seconds
# Year 1979 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 498.36 seconds
# Year 1980 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 503.63 seconds
# Year 1981 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 504.71 seconds
# Year 1982 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 474.35 seconds
# Year 1983 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 467.95 seconds
# Year 1984 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 453.91 seconds
# Year 1985 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 530.67 seconds
# Year 1986 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 651.14 seconds
# Year 1987 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 764.06 seconds
# Year 1988 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 893.39 seconds
# Year 1989 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 958.11 seconds
# Year 1990 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 992.70 seconds
# Year 1991 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1018.83 seconds
# Year 1992 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1052.50 seconds
# Year 1993 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1065.81 seconds
# Year 1994 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1038.49 seconds
# Year 1995 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1047.13 seconds
# Year 1996 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1065.84 seconds
# Year 1997 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1116.90 seconds
# Year 1998 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1150.21 seconds
# Year 1999 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1187.79 seconds
# Year 2000 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1232.32 seconds
# Year 2001 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1248.06 seconds
# Year 2002 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1279.26 seconds
# Year 2003 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1235.37 seconds
# Year 2004 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1177.33 seconds
# Year 2005 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1114.42 seconds
# Year 2006 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 1011.28 seconds
# Year 2007 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 935.26 seconds
# Year 2008 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 882.45 seconds
# Year 2009 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 854.90 seconds
# Year 2010 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 870.44 seconds
# Year 2011 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 855.37 seconds
# Year 2012 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 832.67 seconds
# Year 2013 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 792.57 seconds
# Year 2014 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 693.10 seconds
# Year 2015 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 662.49 seconds
# Year 2016 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 640.62 seconds
# Year 2017 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 637.94 seconds
# Year 2018 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 638.80 seconds
# Year 2019 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 635.06 seconds
# Year 2020 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 607.72 seconds
# Year 2021 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 602.50 seconds
# Year 2022 - Best n_estimators: 10, Best max_depth: 5, Best ACC: 1.0, Time: 594.97 seconds
# Total time: 38676.57 seconds

# %% [markdown]
# ## Forming Portfolios, Value-weighted portfolio returns

# %%
df.head()
# Out:
#    PERMNO       date  y       RET      LME       ME  bull_D    bear_D  bull_W  \
# 0   31464 1970-04-30  0 -0.102941  41412.0  37149.0     0.0  0.000000     0.0
# 1   31464 1970-05-31  0 -0.065574  37149.0  34713.0     0.0  0.000000     0.0
# 2   31464 1970-06-30  0 -0.143860  34713.0  29232.0     0.0  0.000000     0.0
# 3   31464 1970-07-31  0 -0.125000  29232.0  25578.0     0.0  0.083333     0.0
# 4   31464 1970-08-31  1  0.047619  25578.0  26796.0     0.0  0.000000     0.0
#
#      bear_W  bull_M    bear_M  SPREAD_L  LTURNOVER      IVOL     IVOL2  \
# 0  0.166667     0.0  0.416667  0.003421   0.000006  0.000046  0.000034
# 1  0.000000     0.0  0.500000  0.004576   0.000006  0.000013  0.000046
# 2  0.250000     0.0  0.583333  0.006530   0.000008  0.000062  0.000013
# 3  0.000000     0.0  0.666667  0.004847   0.000004  0.000020  0.000062
# 4  0.000000     0.0  0.000000  0.003877   0.000005  0.000047  0.000020
#
#       IVOL3       STR       LTR      IMOM       MOM   PCTHIGH      MVOL  \
# 0  0.000047  0.039638  0.731272  0.612170  0.670081  0.413984  0.012852
# 1  0.000034  0.035635  0.722584  0.625955  0.672735  0.400651  0.017869
# 2  0.000046  0.037131  0.721443  0.622612  0.670797  0.455396  0.127382
# 3  0.000013  0.033998  0.698329  0.624735  0.678001  0.447986  0.035887
# 4  0.000062  0.034753  0.687449  0.638067  0.679698  0.391849  0.023573
#
#       MVOL2     MVOL3      LMKT     LMKT2     LMKT3      MMOM     MIMOM  \
# 0  0.012583  0.010420  0.564331  0.723312  0.385732  0.408401  0.496787
# 1  0.012852  0.012583  0.309299  0.564331  0.723312  0.385646  0.535558
# 2  0.017869  0.012852  0.414013  0.309299  0.564331  0.279599  0.494936
# 3  0.127382  0.017869  0.444076  0.414013  0.309299  0.282368  0.548597
# 4  0.035887  0.127382  0.766624  0.444076  0.414013  0.294738  0.536452
#
#        MLTR  release_L       LAT   DPI2A_L     CTO_L     D2A_L     NOA_L  \
# 0  0.647683        1.0  0.000119  0.006682  0.000433  0.000149  0.000386
# 1  0.630483        0.0  0.000119  0.006682  0.000433  0.000149  0.000386
# 2  0.666119        0.0  0.000119  0.006682  0.000433  0.000149  0.000386
# 3  0.589858        1.0  0.000119  0.006682  0.000424  0.000149  0.000386
# 4  0.498298        0.0  0.000119  0.006682  0.000424  0.000149  0.000386
#
#       OL_L     PCM_L    FC2Y_L  INVEST_L     RNA_L     S2E_L    PROF_L  \
# 0  0.00062  0.907359  0.105362  0.000386  0.261588  0.217478  0.304686
# 1  0.00062  0.907359  0.105362  0.000386  0.261588  0.217478  0.304686
# 2  0.00062  0.907359  0.105362  0.000386  0.261588  0.217478  0.304686
# 3  0.00062  0.907347  0.105364  0.000386  0.261588  0.217477  0.304686
# 4  0.00062  0.907347  0.105364  0.000386  0.261588  0.217477  0.304686
#
#        PM_L     ATO_L     ROA_L     FCF_L    A2ME_L    B2ME_L     S2P_L  \
# 0  0.956350  0.008189  0.785605  0.141009  0.001061  0.797682  0.010881
# 1  0.956350  0.008189  0.785605  0.141009  0.001061  0.797682  0.010881
# 2  0.956350  0.008189  0.785605  0.141009  0.001061  0.797682  0.010881
# 3  0.956351  0.008181  0.785544  0.140986  0.001061  0.797682  0.010711
# 4  0.956351  0.008181  0.785544  0.140986  0.001061  0.797682  0.010711
#
#       ROE_L     LEV_L      TQ_L  year  ols_default  ridge_reg_roll5  \
# 0  0.522705  0.000224  0.000016  1970          NaN              NaN
# 1  0.522707  0.000250  0.000014  1970          NaN              NaN
# 2  0.522708  0.000267  0.000013  1970          NaN              NaN
# 3  0.522684  0.000316  0.000011  1970          NaN              NaN
# 4  0.522684  0.000361  0.000010  1970          NaN              NaN
#
#    lasso_reg_roll5  DT_reg_roll5  RF_reg_roll5
# 0              NaN           NaN           NaN
# 1              NaN           NaN           NaN
# 2              NaN           NaN           NaN
# 3              NaN           NaN           NaN
# 4              NaN           NaN           NaN

# %%
prediction_cols
# prediction_cols = ['logit_default','OLS_default','logit_roll6','DT_reg_roll']
# Out:
# ['ols_default',
#  'ridge_reg_roll5',
#  'lasso_reg_roll5',
#  'DT_reg_roll5',
#  'RF_reg_roll5']

# %%
portfolio = df[['date', 'RET', 'ME', 'y'] + prediction_cols].copy()
portfolio['date'] = pd.to_datetime(portfolio['date'])

# drop rows with missing values
portfolio.dropna(inplace=True)

portfolio.head()
# Out:
#             date       RET         ME  y  ols_default  ridge_reg_roll5  \
# 80751 1976-01-31  0.147541   99391.25  1     0.541998         0.540911
# 80752 1976-01-31  0.266187   87802.00  1     0.657648         0.749225
# 80753 1976-01-31  0.124031  113172.50  1     0.652779         0.710956
# 80754 1976-01-31  0.319444   12801.25  1     1.560148         1.787639
# 80755 1976-01-31  0.000000    8228.50  0     0.383483         0.394166
#
#        lasso_reg_roll5  DT_reg_roll5  RF_reg_roll5
# 80751         0.434048      0.846724      0.835919
# 80752         0.434048      0.954098      0.937994
# 80753         0.447411      1.000000      1.000000
# 80754         0.474138      1.000000      1.000000
# 80755         0.434048      0.000000      0.000000

# %%
portfolio.tail()
# Out:
#               date       RET            ME  y  ols_default  ridge_reg_roll5  \
# 1795158 2022-07-31 -0.211268  3.603768e+05  0     0.456078         0.683612
# 1795159 2022-07-31  0.020794  9.562860e+05  1     0.816904         0.921402
# 1795160 2022-07-31  0.066548  9.219528e+05  1     0.700782         0.761772
# 1795161 2022-07-31  0.087452  1.216028e+05  1     0.900600         0.914907
# 1795162 2022-07-31  0.323765  9.311106e+08  1     0.814605         0.876090
#
#          lasso_reg_roll5  DT_reg_roll5  RF_reg_roll5
# 1795158         0.497137      0.000000      0.000000
# 1795159         0.665507      1.000000      1.000000
# 1795160         0.521968      0.993929      0.991815
# 1795161         0.521968      0.993929      0.988957
# 1795162         0.521968      0.993929      0.993056

# %%
# Initialize an empty DataFrame to store value-weighted returns for each model
vwreturns = pd.DataFrame(portfolio['date'].unique(), columns=['date'])  # Ensures all dates are included

for pred_col in prediction_cols:
    # Calculate deciles for this prediction
    decile_col = f'decile_{pred_col}'
    portfolio[decile_col] = portfolio.groupby(['date'])[pred_col].transform(lambda x: pd.qcut(x, 10, labels=False, duplicates='drop'))
    
    # Determine position based on deciles
    position_col = f'position_{pred_col}'
    portfolio[position_col] = np.where(portfolio[decile_col] == 9, 1, np.where(portfolio[decile_col] == 0, -1, 0))
    
    # Calculate the value-weighted return for this prediction
    vwret_col = f'vwreturn_{pred_col}'
    vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
    
    # Merge the temporary value-weighted returns with the main vwreturns DataFrame
    vwreturns = vwreturns.merge(vwreturns_temp, on='date', how='left')

# Ensure the 'date' column is the first column and is sorted
vwreturns = vwreturns.sort_values('date').reset_index(drop=True)
# Out:
# /tmp/ipykernel_26/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_26/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_26/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_26/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_26/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_reg_roll5  \
# 0 1976-01-31              0.030443                  0.032248
# 1 1976-02-29              0.015261                  0.014575
# 2 1976-03-31              0.010497                  0.010523
# 3 1976-04-30              0.010684                  0.006683
# 4 1976-05-31              0.020038                  0.019607
#
#    vwreturn_lasso_reg_roll5  vwreturn_DT_reg_roll5  vwreturn_RF_reg_roll5
# 0                 -0.085951              -0.001281              -0.001266
# 1                  0.008840              -0.009918              -0.009918
# 2                  0.005309               0.005947               0.008930
# 3                  0.002828               0.026945               0.026956
# 4                  0.005792               0.025408               0.025408

# %% [markdown]
# ### Compare to market data

# %%
#market = pd.read_csv('FF3_clean.csv')
market = pd.read_csv('/kaggle/input/sign-prediction-datasets/FF3_clean.csv')

# %%
market.head()
# Out:
#          date  Mkt-RF   SMB   HML    RF
# 0  1926-07-31    2.96 -2.56 -2.43  0.22
# 1  1926-08-31    2.64 -1.17  3.82  0.25
# 2  1926-09-30    0.36 -1.40  0.13  0.23
# 3  1926-10-31   -3.24 -0.09  0.70  0.32
# 4  1926-11-30    2.53 -0.10 -0.51  0.31

# %%
# create a new 'Mkt' which is a sum of Mkt-RF and RF
market['Mkt'] = market['Mkt-RF'] + market['RF']

# divide all columns by 100 except 'date'
market.iloc[:, 1:] = market.iloc[:, 1:] / 100

#set the 'date' column to datetime format
market['date'] = pd.to_datetime(market['date'])

# merge the market data (only date and Mkt columns) with the vwreturns DataFrame
vwreturns = vwreturns.merge(market[['date', 'Mkt']], on='date', how='left')

# transform all columns (except 'date') to a log: log(x+1) and save the result as lvwreturns
lvwreturns = vwreturns.copy()
lvwreturns.iloc[:, 1:] = np.log(vwreturns.iloc[:, 1:] + 1)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_reg_roll5  \
# 0 1976-01-31              0.030443                  0.032248
# 1 1976-02-29              0.015261                  0.014575
# 2 1976-03-31              0.010497                  0.010523
# 3 1976-04-30              0.010684                  0.006683
# 4 1976-05-31              0.020038                  0.019607
#
#    vwreturn_lasso_reg_roll5  vwreturn_DT_reg_roll5  vwreturn_RF_reg_roll5  \
# 0                 -0.085951              -0.001281              -0.001266
# 1                  0.008840              -0.009918              -0.009918
# 2                  0.005309               0.005947               0.008930
# 3                  0.002828               0.026945               0.026956
# 4                  0.005792               0.025408               0.025408
#
#       Mkt
# 0  0.1263
# 1  0.0066
# 2  0.0272
# 3 -0.0107
# 4 -0.0097

# %%
lvwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_reg_roll5  \
# 0 1976-01-31              0.029989                  0.031739
# 1 1976-02-29              0.015146                  0.014469
# 2 1976-03-31              0.010442                  0.010468
# 3 1976-04-30              0.010628                  0.006661
# 4 1976-05-31              0.019840                  0.019417
#
#    vwreturn_lasso_reg_roll5  vwreturn_DT_reg_roll5  vwreturn_RF_reg_roll5  \
# 0                 -0.089872              -0.001282              -0.001266
# 1                  0.008801              -0.009967              -0.009967
# 2                  0.005295               0.005930               0.008891
# 3                  0.002824               0.026588               0.026599
# 4                  0.005775               0.025091               0.025091
#
#         Mkt
# 0  0.118938
# 1  0.006578
# 2  0.026837
# 3 -0.010758
# 4 -0.009747

# %%
lvwreturns.describe()
# Out:
#                                 date  vwreturn_ols_default  \
# count                            559            559.000000
# mean   1999-05-01 04:22:45.295169920              0.016571
# min              1976-01-31 00:00:00             -0.020252
# 25%              1987-09-15 00:00:00              0.010928
# 50%              1999-04-30 00:00:00              0.014409
# 75%              2010-12-15 12:00:00              0.019833
# max              2022-07-31 00:00:00              0.077408
# std                              NaN              0.008660
#
#        vwreturn_ridge_reg_roll5  vwreturn_lasso_reg_roll5  \
# count                559.000000                559.000000
# mean                   0.016952                  0.004610
# min                   -0.031658                 -0.089872
# 25%                    0.011345                  0.002202
# 50%                    0.014991                  0.003609
# 75%                    0.020550                  0.006425
# max                    0.077671                  0.031222
# std                    0.008958                  0.005997
#
#        vwreturn_DT_reg_roll5  vwreturn_RF_reg_roll5         Mkt
# count             559.000000             559.000000  559.000000
# mean                0.021938               0.023459    0.009303
# min                -0.054603              -0.050184   -0.256700
# 25%                 0.007739               0.009082   -0.015672
# 50%                 0.015368               0.016978    0.013804
# 75%                 0.029013               0.030096    0.038162
# max                 0.207532               0.207532    0.127953
# std                 0.023857               0.022670    0.045169

# %%
# save the lvwreturns and portfolio DataFrame to a parquet file into 'outputs' folder

# for reproducibility and visualization purposes
lvwreturns.to_parquet('fin_lvwreturns_reg1.parquet')
portfolio.to_parquet('fin_portfolio_reg1.parquet')

# save vwreturns DataFrame to a .dta file into 'outputs' folder
#vwreturns.to_stata('outputs/vwreturns.dta') # for backtasting in R - we need normal returns, not log returns
