# %% [markdown]
# # Framework for predictions and portfolio forming

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import time

# import the parquet library
import pyarrow.parquet as pq

# import model libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
# load 'basemodel.parquet'
#df = pd.read_parquet('basemodel.parquet')
df = pd.read_parquet('/kaggle/input/sign-prediction-datasets/basemodel.parquet')
prediction_cols = []
df.head()
# Out:
#    PERMNO       date       RET           ME  bull_D  bear_D  bull_W  bear_W  \
# 0   10000 1986-02-28 -0.257143  11960.00000     0.0     0.0     0.0     1.0
# 1   10000 1986-03-31  0.365385  16330.00000     0.0     0.0     0.0     0.0
# 2   10000 1986-04-30 -0.098592  15172.00000     0.0     1.0     0.0     0.0
# 3   10000 1986-05-31 -0.222656  11793.87834     0.0     0.0     0.0     0.0
# 4   10000 1986-06-30 -0.005025  11734.59375     0.0     0.0     0.0     0.0
#
#    bull_M  bear_M    LMKT      IVOL  y
# 0       0       0  0.0121  0.004058  0
# 1       0       0  0.0766  0.000973  1
# 2       0       0  0.0548  0.001993  0
# 3       0       1 -0.0079  0.000163  0
# 4       0       2  0.0511  0.001569  0

# %%
# select the columns to be used for prediction
X_col = ['bull_D', 'bear_D', 'bull_W', 'bear_W', 'bull_M', 'bear_M', 'LMKT', 'IVOL']

# %%
# Convert 'date' to datetime format (if not already done) and sort the DataFrame
df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)
df.reset_index(drop=True, inplace=True)

# Create a 'year' column based on the 'date' column
df['year'] = df['date'].dt.year

# %% [markdown]
# # Paper Replication - OLS and Logit, Expanding Window - No Hyperparameters
# - They start with out of sample forecasting in 1932
# - models will be named model_default

# %% [markdown]
# ### Linear Regression (Pooled OLS)

# %%
#################################
# OLS, default, exp window
#################################

model_name = 'ols_default'


# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

for year in range(df['year'].min() + 6, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Define the training data up until this year
    train_data = df[df['year'] < year]
    
    X_train = train_data[X_col]
    y_train = train_data['y']
    
    # Train the Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict(X_next_year)
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Time: {iteration_time:.2f} seconds")
# Out:
# Year 1932 - Time: 0.06 seconds
# Year 1933 - Time: 0.05 seconds
# Year 1934 - Time: 0.05 seconds
# Year 1935 - Time: 0.05 seconds
# Year 1936 - Time: 0.07 seconds
# Year 1937 - Time: 0.06 seconds
# Year 1938 - Time: 0.06 seconds
# Year 1939 - Time: 0.06 seconds
# Year 1940 - Time: 0.07 seconds
# Year 1941 - Time: 0.07 seconds
# Year 1942 - Time: 0.07 seconds
# Year 1943 - Time: 0.08 seconds
# Year 1944 - Time: 0.08 seconds
# %%
df.tail()
# Out:
#          PERMNO       date       RET            ME  bull_D  bear_D  bull_W  \
# 3627748   14436 2022-07-31 -0.106939  3.731571e+06     2.0     0.0     0.0
# 3627749   14435 2022-07-31  0.020969  5.066263e+03     0.0     0.0     0.0
# 3627750   14434 2022-07-31  0.184785  1.280287e+06     0.0     0.0     3.0
# 3627751   14431 2022-07-31  0.108881  3.475711e+04     0.0     1.0     0.0
# 3627752   93436 2022-07-31  0.323765  9.311106e+08     2.0     0.0     1.0
#
#          bear_W  bull_M  bear_M    LMKT      IVOL  y  year  ols_default
# 3627748     0.0       0       0 -0.0837  0.001066  0  2022     0.626592
# 3627749     0.0       0       0 -0.0837  0.003461  1  2022     0.526688
# 3627750     0.0       0       0 -0.0837  0.000616  1  2022     0.799235
# 3627751     0.0       0       0 -0.0837  0.004084  1  2022     0.493767
# 3627752     0.0       0       0 -0.0837  0.000625  1  2022     0.717418

# %% [markdown]
# # My Experiments

# %% [markdown]
# ## Machine Learning - Hyperparameter Tuning included in the process
# - models to be named 'model_clas/reg_exp/roll'

# %% [markdown]
# ### Expanding Window Estimation

# %% [markdown]
# ##### MSE as evaluation metric

# %%
###################################
# RIDGE CLASSIFICATION MODEL  - MSE
###################################

model_name = 'ridge_clas_exp_MSE'  # Define the model name for Ridge

# Update the column name for storing Ridge classification predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the regularization strengths to test
HP1 = [0.01, 0.1, 1, 10, 100]  # Regularization strength C

for year in range(df['year'].min() + 7, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Define training and tuning datasets
    train_data = df[df['year'] < year]
    tuning_data = train_data[train_data['year'] == year - 1]
    train_data = train_data[train_data['year'] < year - 1]
    
    X_train = train_data[X_col]
    y_train = train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = float('inf')  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = LogisticRegression(C=hp1, max_iter=1000, penalty='l2')  # Ridge
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training dataset up to the current year
    X_full_train = df[df['year'] < year][X_col]
    y_full_train = df[df['year'] < year]['y']
    model = LogisticRegression(C=best_HP1, max_iter=1000, penalty='l2')  # Ridge
    model.fit(X_full_train, y_full_train)
    
    # Predict probabilities for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best C: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Year 2011 - Best C: 100, Best MSE: 0.089, Time: 39.89 seconds
# Year 2012 - Best C: 100, Best MSE: 0.0927, Time: 38.70 seconds
# Year 2013 - Best C: 10, Best MSE: 0.0987, Time: 48.82 seconds
# Year 2014 - Best C: 100, Best MSE: 0.0963, Time: 44.18 seconds
# Year 2015 - Best C: 100, Best MSE: 0.0924, Time: 42.02 seconds
# Year 2016 - Best C: 100, Best MSE: 0.1019, Time: 42.83 seconds
# Year 2017 - Best C: 100, Best MSE: 0.0941, Time: 42.60 seconds
# Year 2018 - Best C: 100, Best MSE: 0.1013, Time: 44.35 seconds
# Year 2019 - Best C: 10, Best MSE: 0.101, Time: 47.78 seconds
# Year 2020 - Best C: 100, Best MSE: 0.0911, Time: 44.99 seconds
# Year 2021 - Best C: 100, Best MSE: 0.0864, Time: 43.91 seconds
# Year 2022 - Best C: 100, Best MSE: 0.0983, Time: 45.98 seconds

# %%
###################################
# DT CLASSIFICATION MODEL  - MSE
###################################

model_name = 'DT_clas_exp_MSE'  # Define the model name for Ridge

# Update the column name for storing Ridge classification predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

HP1 = [5, 10, 15, 20, 25, None]  # Max depth of the tree

for year in range(df['year'].min() + 7, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Define training and tuning datasets
    train_data = df[df['year'] < year]
    tuning_data = train_data[train_data['year'] == year - 1]
    train_data = train_data[train_data['year'] < year - 1]
    
    X_train = train_data[X_col]
    y_train = train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = float('inf')  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = DecisionTreeClassifier(max_depth=hp1)
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training dataset up to the current year
    X_full_train = df[df['year'] < year][X_col]
    y_full_train = df[df['year'] < year]['y']
    model = DecisionTreeClassifier(max_depth=best_HP1)
    model.fit(X_full_train, y_full_train)
    
    # Predict probabilities for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best Max Depth: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Out:
# Year 1933 - Best Max Depth: 10, Best MSE: 0.0955, Time: 0.59 seconds
# Year 1934 - Best Max Depth: 10, Best MSE: 0.0928, Time: 0.68 seconds
# Year 1935 - Best Max Depth: 10, Best MSE: 0.108, Time: 0.80 seconds
# Year 1936 - Best Max Depth: 10, Best MSE: 0.1102, Time: 0.98 seconds
# Year 2009 - Best Max Depth: 10, Best MSE: 0.0943, Time: 93.73 seconds
# Year 2010 - Best Max Depth: 10, Best MSE: 0.0993, Time: 94.01 seconds
# Year 2011 - Best Max Depth: 15, Best MSE: 0.0867, Time: 98.55 seconds
# Year 2012 - Best Max Depth: 10, Best MSE: 0.0935, Time: 97.15 seconds
# Year 2013 - Best Max Depth: 10, Best MSE: 0.0976, Time: 100.82 seconds
# Year 2014 - Best Max Depth: 10, Best MSE: 0.0907, Time: 101.21 seconds
# Year 2015 - Best Max Depth: 10, Best MSE: 0.0912, Time: 101.58 seconds
# Year 2016 - Best Max Depth: 10, Best MSE: 0.1005, Time: 104.41 seconds
# Year 2017 - Best Max Depth: 10, Best MSE: 0.0939, Time: 105.53 seconds
# Year 2018 - Best Max Depth: 10, Best MSE: 0.1002, Time: 109.08 seconds
# Year 2019 - Best Max Depth: 10, Best MSE: 0.0971, Time: 112.31 seconds
# Year 2020 - Best Max Depth: 15, Best MSE: 0.0895, Time: 114.61 seconds
# Year 2021 - Best Max Depth: 10, Best MSE: 0.089, Time: 112.41 seconds
# Year 2022 - Best Max Depth: 15, Best MSE: 0.0955, Time: 117.61 seconds

# %% [markdown]
# ### First expanding, then rolling
# start predicting for 1932, expand the window until you reach X years, then roll it

# %% [markdown]
# #### MSE Evaluation

# %% [markdown]
# ##### 5 years

# %%
rolling_window = 5

# %%
############################################
# RIDGE CLASSIFICATION MODEL - MSE
############################################

model_name = 'ridge_clas_roll5_MSE'  # Name of the new column for storing predictions

# Predefined set of C values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100] # C

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
       
    best_HP1 = None
    best_mse = float('inf')  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = LogisticRegression(C=hp1, max_iter=1000, penalty='l2')  # Ridge
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    
    # Retrain on the entire training window (excluding tuning year) with the best C value
    model = LogisticRegression(C=best_HP1, max_iter=1000, penalty='l2')
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best C: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Out:
# Year 1933 - Best C: 0.1, Best MSE: 0.0985, Time: 0.45 seconds
# Year 1934 - Best C: 100, Best MSE: 0.0866, Time: 0.44 seconds
# Year 1935 - Best C: 100, Best MSE: 0.1018, Time: 0.44 seconds
# Year 1936 - Best C: 0.1, Best MSE: 0.1087, Time: 0.41 seconds
# Year 1937 - Best C: 100, Best MSE: 0.1009, Time: 0.43 seconds
# Year 1938 - Best C: 1, Best MSE: 0.0789, Time: 0.50 seconds
# Year 1939 - Best C: 100, Best MSE: 0.0875, Time: 0.63 seconds
# Year 1940 - Best C: 100, Best MSE: 0.0788, Time: 0.73 seconds
# Year 1941 - Best C: 100, Best MSE: 0.1071, Time: 0.57 seconds
# Year 1942 - Best C: 0.1, Best MSE: 0.1098, Time: 0.93 seconds
# Year 1943 - Best C: 0.1, Best MSE: 0.1077, Time: 0.57 seconds
# Year 1944 - Best C: 100, Best MSE: 0.0899, Time: 0.72 seconds
# Year 1945 - Best C: 100, Best MSE: 0.1057, Time: 0.69 seconds
# Year 1946 - Best C: 100, Best MSE: 0.0781, Time: 0.67 seconds
# Year 1947 - Best C: 100, Best MSE: 0.0825, Time: 0.66 seconds
# Year 1948 - Best C: 1, Best MSE: 0.1029, Time: 0.62 seconds
# Year 1949 - Best C: 100, Best MSE: 0.0856, Time: 0.80 seconds
# Year 1950 - Best C: 100, Best MSE: 0.1086, Time: 0.70 seconds
# Year 1951 - Best C: 100, Best MSE: 0.0935, Time: 0.93 seconds
# Year 1952 - Best C: 100, Best MSE: 0.0908, Time: 0.92 seconds
# Year 1953 - Best C: 100, Best MSE: 0.0962, Time: 0.95 seconds
# Year 1954 - Best C: 1, Best MSE: 0.1039, Time: 0.87 seconds
# Year 1955 - Best C: 100, Best MSE: 0.0899, Time: 1.09 seconds
# Year 1956 - Best C: 100, Best MSE: 0.1069, Time: 1.14 seconds
# Year 1957 - Best C: 1, Best MSE: 0.0959, Time: 1.08 seconds
# Year 1958 - Best C: 0.1, Best MSE: 0.0989, Time: 0.86 seconds
# Year 1959 - Best C: 100, Best MSE: 0.088, Time: 1.02 seconds
# Year 1960 - Best C: 1, Best MSE: 0.107, Time: 0.91 seconds
# Year 1961 - Best C: 100, Best MSE: 0.0976, Time: 0.84 seconds
# Year 1962 - Best C: 100, Best MSE: 0.0957, Time: 1.17 seconds
# Year 1963 - Best C: 1, Best MSE: 0.0858, Time: 1.10 seconds
# Year 1964 - Best C: 100, Best MSE: 0.1128, Time: 1.11 seconds
# Year 1965 - Best C: 100, Best MSE: 0.1181, Time: 1.60 seconds
# Year 1966 - Best C: 100, Best MSE: 0.1032, Time: 1.67 seconds
# Year 2006 - Best C: 100, Best MSE: 0.0947, Time: 3.63 seconds
# Year 2007 - Best C: 100, Best MSE: 0.1014, Time: 3.70 seconds
# Year 2008 - Best C: 1, Best MSE: 0.0952, Time: 4.42 seconds
# Year 2009 - Best C: 0.1, Best MSE: 0.0911, Time: 3.87 seconds
# Year 2010 - Best C: 0.1, Best MSE: 0.0968, Time: 4.78 seconds
# Year 2011 - Best C: 100, Best MSE: 0.0895, Time: 3.66 seconds
# Year 2012 - Best C: 100, Best MSE: 0.0914, Time: 2.91 seconds
# Year 2013 - Best C: 100, Best MSE: 0.098, Time: 2.42 seconds
# Year 2014 - Best C: 100, Best MSE: 0.0924, Time: 2.88 seconds
# Year 2015 - Best C: 100, Best MSE: 0.0897, Time: 2.94 seconds
# Year 2016 - Best C: 0.1, Best MSE: 0.1023, Time: 3.11 seconds
# Year 2017 - Best C: 0.1, Best MSE: 0.0931, Time: 3.58 seconds
# Year 2018 - Best C: 100, Best MSE: 0.1004, Time: 3.41 seconds
# Year 2019 - Best C: 100, Best MSE: 0.0955, Time: 2.79 seconds
# Year 2020 - Best C: 100, Best MSE: 0.0842, Time: 3.17 seconds
# Year 2021 - Best C: 0.1, Best MSE: 0.0854, Time: 2.87 seconds
# Year 2022 - Best C: 100, Best MSE: 0.0957, Time: 3.53 seconds

# %%
############################################
# DECISION TREE CLASSIFICATION MODEL
############################################

model_name = 'DT_class_roll5_MSE'


# Predefined set of max_depth values for hyperparameter tuning
HP1 = [3, 5, 10, 15, 25, None] # max_depth

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Timing each iteration
    
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = float('inf')
    
    # Hyperparameter tuning for max_depth
    for hp1 in HP1:
        model = DecisionTreeClassifier(max_depth=hp1)
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training window with the best max_depth value
    model = DecisionTreeClassifier(max_depth=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict_proba(X_next_year)[:, 1]
        df.loc[df['year'] == year, model_name] = next_year_predictions
    
    end_time = time.time()
    iteration_time = end_time - start_time
    
    print(f"Year {year} - Best Max Depth: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Year 2005 - Best Max Depth: 10, Best MSE: 0.0972, Time: 4.22 seconds
# Year 2006 - Best Max Depth: 10, Best MSE: 0.0948, Time: 3.84 seconds
# Year 2007 - Best Max Depth: 10, Best MSE: 0.1023, Time: 3.54 seconds
# Year 2008 - Best Max Depth: 10, Best MSE: 0.0987, Time: 3.41 seconds
# Year 2009 - Best Max Depth: 10, Best MSE: 0.0921, Time: 3.47 seconds
# Year 2010 - Best Max Depth: 5, Best MSE: 0.1, Time: 3.10 seconds
# Year 2011 - Best Max Depth: 10, Best MSE: 0.085, Time: 3.21 seconds
# Year 2012 - Best Max Depth: 5, Best MSE: 0.0974, Time: 2.85 seconds
# Year 2013 - Best Max Depth: 10, Best MSE: 0.0997, Time: 2.86 seconds
# Year 2014 - Best Max Depth: 10, Best MSE: 0.0924, Time: 2.67 seconds
# Year 2015 - Best Max Depth: 5, Best MSE: 0.0996, Time: 2.42 seconds
# Year 2016 - Best Max Depth: 10, Best MSE: 0.1078, Time: 2.49 seconds
# Year 2017 - Best Max Depth: 5, Best MSE: 0.0964, Time: 2.47 seconds
# Year 2018 - Best Max Depth: 10, Best MSE: 0.1053, Time: 2.51 seconds
# Year 2019 - Best Max Depth: 5, Best MSE: 0.1039, Time: 2.45 seconds
# Year 2020 - Best Max Depth: 10, Best MSE: 0.0911, Time: 2.60 seconds
# Year 2021 - Best Max Depth: 5, Best MSE: 0.0998, Time: 2.46 seconds
# Year 2022 - Best Max Depth: 5, Best MSE: 0.1019, Time: 2.41 seconds

# %% [markdown]
# ##### 10 years

# %%
rolling_window = 10

# %%
############################################
# RIDGE CLASSIFICATION MODEL - MSE
############################################

model_name = 'ridge_clas_roll10_MSE'  # Name of the new column for storing predictions

# Predefined set of C values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100] # C

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
       
    best_HP1 = None
    best_mse = float('inf')  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = LogisticRegression(C=hp1, max_iter=1000, penalty='l2')  # Ridge
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    
    # Retrain on the entire training window (excluding tuning year) with the best C value
    model = LogisticRegression(C=best_HP1, max_iter=1000, penalty='l2')
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best C: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Out:
# Year 1933 - Best C: 0.1, Best MSE: 0.0988, Time: 0.57 seconds
# Year 1934 - Best C: 100, Best MSE: 0.0854, Time: 0.64 seconds
# Year 1935 - Best C: 100, Best MSE: 0.101, Time: 0.73 seconds
# Year 1936 - Best C: 0.1, Best MSE: 0.1083, Time: 0.77 seconds
# Year 1937 - Best C: 100, Best MSE: 0.0997, Time: 1.13 seconds
# Year 1938 - Best C: 100, Best MSE: 0.0782, Time: 1.15 seconds
# Year 1939 - Best C: 100, Best MSE: 0.0971, Time: 0.88 seconds
# Year 1940 - Best C: 100, Best MSE: 0.0891, Time: 0.94 seconds
# Year 1941 - Best C: 100, Best MSE: 0.106, Time: 0.99 seconds
# Year 1942 - Best C: 100, Best MSE: 0.1095, Time: 1.09 seconds
# Year 1943 - Best C: 0.1, Best MSE: 0.1076, Time: 1.03 seconds
# Year 1944 - Best C: 100, Best MSE: 0.0907, Time: 1.22 seconds
# Year 1945 - Best C: 100, Best MSE: 0.1042, Time: 1.41 seconds
# Year 1946 - Best C: 100, Best MSE: 0.0766, Time: 1.22 seconds
# Year 1947 - Best C: 100, Best MSE: 0.0814, Time: 1.33 seconds
# Year 1948 - Best C: 1, Best MSE: 0.1024, Time: 1.36 seconds
# Year 1949 - Best C: 100, Best MSE: 0.0862, Time: 1.54 seconds
# Year 1950 - Best C: 100, Best MSE: 0.1098, Time: 1.64 seconds
# Year 1951 - Best C: 100, Best MSE: 0.0934, Time: 1.71 seconds
# Year 1952 - Best C: 100, Best MSE: 0.0909, Time: 1.61 seconds
# Year 1953 - Best C: 100, Best MSE: 0.0957, Time: 1.55 seconds
# Year 1954 - Best C: 1, Best MSE: 0.1029, Time: 1.97 seconds
# Year 1955 - Best C: 100, Best MSE: 0.0897, Time: 2.13 seconds
# Year 1956 - Best C: 100, Best MSE: 0.1063, Time: 2.14 seconds
# Year 1957 - Best C: 1, Best MSE: 0.0958, Time: 2.05 seconds
# Year 1958 - Best C: 0.1, Best MSE: 0.0992, Time: 1.83 seconds
# Year 1959 - Best C: 100, Best MSE: 0.088, Time: 2.26 seconds
# Year 1960 - Best C: 1, Best MSE: 0.1074, Time: 2.00 seconds
# Year 1961 - Best C: 100, Best MSE: 0.0976, Time: 2.15 seconds
# Year 1962 - Best C: 100, Best MSE: 0.0958, Time: 1.98 seconds
# Year 1963 - Best C: 1, Best MSE: 0.0855, Time: 2.21 seconds
# Year 2004 - Best C: 10, Best MSE: 0.0986, Time: 11.60 seconds
# Year 2005 - Best C: 100, Best MSE: 0.0962, Time: 9.83 seconds
# Year 2006 - Best C: 10, Best MSE: 0.0944, Time: 10.71 seconds
# Year 2007 - Best C: 100, Best MSE: 0.1018, Time: 8.93 seconds
# Year 2008 - Best C: 10, Best MSE: 0.0959, Time: 8.84 seconds
# Year 2009 - Best C: 1, Best MSE: 0.0903, Time: 8.52 seconds
# Year 2010 - Best C: 0.1, Best MSE: 0.0968, Time: 7.97 seconds
# Year 2011 - Best C: 10, Best MSE: 0.0902, Time: 6.75 seconds
# Year 2012 - Best C: 10, Best MSE: 0.0912, Time: 7.85 seconds
# Year 2013 - Best C: 100, Best MSE: 0.0975, Time: 6.81 seconds
# Year 2014 - Best C: 100, Best MSE: 0.0935, Time: 7.53 seconds
# Year 2015 - Best C: 100, Best MSE: 0.0912, Time: 6.71 seconds
# Year 2016 - Best C: 100, Best MSE: 0.1021, Time: 7.71 seconds
# Year 2017 - Best C: 100, Best MSE: 0.0931, Time: 6.77 seconds
# Year 2018 - Best C: 100, Best MSE: 0.1008, Time: 6.38 seconds
# Year 2019 - Best C: 10, Best MSE: 0.0969, Time: 5.74 seconds
# Year 2020 - Best C: 100, Best MSE: 0.0835, Time: 5.88 seconds
# Year 2021 - Best C: 0.1, Best MSE: 0.0862, Time: 6.28 seconds
# Year 2022 - Best C: 1, Best MSE: 0.096, Time: 7.06 seconds

# %%
############################################
# DECISION TREE CLASSIFICATION MODEL
############################################

model_name = 'DT_class_roll10_MSE'


# Predefined set of max_depth values for hyperparameter tuning
HP1 = [3, 5, 10, 15, 25, None] # max_depth

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Timing each iteration
    
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = float('inf')
    
    # Hyperparameter tuning for max_depth
    for hp1 in HP1:
        model = DecisionTreeClassifier(max_depth=hp1)
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training window with the best max_depth value
    model = DecisionTreeClassifier(max_depth=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_predictions = model.predict_proba(X_next_year)[:, 1]
        df.loc[df['year'] == year, model_name] = next_year_predictions
# Year 2003 - Best Max Depth: 10, Best MSE: 0.0975, Time: 16.75 seconds
# Year 2004 - Best Max Depth: 10, Best MSE: 0.0996, Time: 17.19 seconds
# Year 2005 - Best Max Depth: 10, Best MSE: 0.0956, Time: 15.96 seconds
# Year 2006 - Best Max Depth: 10, Best MSE: 0.0962, Time: 14.95 seconds
# Year 2007 - Best Max Depth: 10, Best MSE: 0.1014, Time: 13.83 seconds
# Year 2008 - Best Max Depth: 10, Best MSE: 0.0958, Time: 12.97 seconds
# Year 2009 - Best Max Depth: 10, Best MSE: 0.0958, Time: 11.84 seconds
# Year 2010 - Best Max Depth: 10, Best MSE: 0.0997, Time: 11.11 seconds
# Year 2011 - Best Max Depth: 10, Best MSE: 0.0889, Time: 9.96 seconds
# Year 2012 - Best Max Depth: 5, Best MSE: 0.0955, Time: 8.66 seconds
# Year 2013 - Best Max Depth: 10, Best MSE: 0.0982, Time: 8.73 seconds
# Year 2014 - Best Max Depth: 5, Best MSE: 0.0896, Time: 8.37 seconds
# Year 2015 - Best Max Depth: 10, Best MSE: 0.0943, Time: 8.47 seconds
# Year 2016 - Best Max Depth: 10, Best MSE: 0.104, Time: 7.96 seconds
# Year 2017 - Best Max Depth: 5, Best MSE: 0.0991, Time: 7.32 seconds
# Year 2018 - Best Max Depth: 10, Best MSE: 0.1044, Time: 7.31 seconds
# Year 2019 - Best Max Depth: 10, Best MSE: 0.1, Time: 7.29 seconds
# Year 2020 - Best Max Depth: 10, Best MSE: 0.0927, Time: 7.04 seconds
# Year 2021 - Best Max Depth: 10, Best MSE: 0.0871, Time: 7.14 seconds
# Year 2022 - Best Max Depth: 10, Best MSE: 0.0982, Time: 7.20 seconds

# %% [markdown]
# ##### 20 years

# %%
rolling_window = 20

# %%
############################################
# RIDGE CLASSIFICATION MODEL - MSE
############################################

model_name = 'ridge_clas_roll20_MSE'  # Name of the new column for storing predictions

# Predefined set of C values for hyperparameter tuning
HP1 = [0.01, 0.1, 1, 10, 100] # C

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

# Define the start year for modeling based on having at least 7 years of data
start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Start timing
    
    # Determine the start year of the training window based on the current year
    train_start_year = max(year - rolling_window, df['year'].min())  # Ensure it does not go below the earliest year
    
    # Select the training data based on the calculated start year
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    # Split training data into actual training and tuning sets
    # Use the last year of the training data for tuning
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
       
    best_HP1 = None
    best_mse = float('inf')  # Initialize with infinity
    
    # Hyperparameter tuning
    for hp1 in HP1:
        model = LogisticRegression(C=hp1, max_iter=1000, penalty='l2')  # Ridge
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]  # Get probabilities of the positive class
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    
    # Retrain on the entire training window (excluding tuning year) with the best C value
    model = LogisticRegression(C=best_HP1, max_iter=1000, penalty='l2')
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
    X_next_year = next_year_data[X_col]
    
    if not X_next_year.empty:
        next_year_probabilities = model.predict_proba(X_next_year)[:, 1]  # Probability of the positive class
        df.loc[df['year'] == year, model_name] = next_year_probabilities
    
    end_time = time.time()  # End timing
    iteration_time = end_time - start_time  # Calculate iteration time
    
    print(f"Year {year} - Best C: {best_HP1}, Best MSE: {round(best_mse,4)}, Time: {iteration_time:.2f} seconds")
# Out:
# Year 1933 - Best C: 0.1, Best MSE: 0.0988, Time: 0.56 seconds
# Year 1934 - Best C: 100, Best MSE: 0.0854, Time: 0.64 seconds
# Year 1935 - Best C: 100, Best MSE: 0.101, Time: 0.75 seconds
# Year 1936 - Best C: 0.1, Best MSE: 0.1083, Time: 0.85 seconds
# Year 1937 - Best C: 100, Best MSE: 0.0996, Time: 0.88 seconds
# Year 1938 - Best C: 100, Best MSE: 0.0783, Time: 0.97 seconds
# Year 1939 - Best C: 100, Best MSE: 0.0948, Time: 1.16 seconds
# Year 1940 - Best C: 100, Best MSE: 0.0879, Time: 1.34 seconds
# Year 1941 - Best C: 100, Best MSE: 0.106, Time: 1.35 seconds
# Year 1942 - Best C: 100, Best MSE: 0.1095, Time: 1.46 seconds
# Year 1943 - Best C: 0.1, Best MSE: 0.1078, Time: 1.53 seconds
# Year 1944 - Best C: 100, Best MSE: 0.0938, Time: 1.53 seconds
# Year 1945 - Best C: 100, Best MSE: 0.107, Time: 2.09 seconds
# Year 1946 - Best C: 100, Best MSE: 0.0807, Time: 1.80 seconds
# Year 1947 - Best C: 100, Best MSE: 0.0833, Time: 2.06 seconds
# Year 1948 - Best C: 100, Best MSE: 0.103, Time: 1.82 seconds
# Year 1949 - Best C: 100, Best MSE: 0.0909, Time: 2.09 seconds
# Year 1950 - Best C: 100, Best MSE: 0.1106, Time: 1.94 seconds
# Year 1951 - Best C: 100, Best MSE: 0.0949, Time: 2.16 seconds
# Year 1952 - Best C: 100, Best MSE: 0.0931, Time: 2.41 seconds
# Year 1953 - Best C: 100, Best MSE: 0.0967, Time: 2.20 seconds
# Year 1954 - Best C: 100, Best MSE: 0.1023, Time: 3.08 seconds
# Year 1955 - Best C: 100, Best MSE: 0.0907, Time: 3.37 seconds
# Year 1956 - Best C: 100, Best MSE: 0.1066, Time: 3.29 seconds
# Year 1957 - Best C: 1, Best MSE: 0.0956, Time: 4.23 seconds
# Year 1958 - Best C: 0.01, Best MSE: 0.0993, Time: 3.29 seconds
# Year 1959 - Best C: 100, Best MSE: 0.0894, Time: 3.18 seconds
# Year 1960 - Best C: 0.1, Best MSE: 0.107, Time: 3.88 seconds
# Year 1961 - Best C: 100, Best MSE: 0.0975, Time: 3.55 seconds
# Year 2001 - Best C: 100, Best MSE: 0.1003, Time: 19.65 seconds
# Year 2002 - Best C: 0.01, Best MSE: 0.1026, Time: 20.87 seconds
# Year 2003 - Best C: 0.01, Best MSE: 0.0951, Time: 23.45 seconds
# Year 2004 - Best C: 10, Best MSE: 0.0995, Time: 20.06 seconds
# Year 2005 - Best C: 100, Best MSE: 0.0969, Time: 18.11 seconds
# Year 2006 - Best C: 10, Best MSE: 0.0947, Time: 21.76 seconds
# Year 2007 - Best C: 10, Best MSE: 0.1019, Time: 20.70 seconds
# Year 2008 - Best C: 10, Best MSE: 0.0965, Time: 22.27 seconds
# Year 2009 - Best C: 0.1, Best MSE: 0.0904, Time: 23.88 seconds
# Year 2010 - Best C: 100, Best MSE: 0.0973, Time: 20.63 seconds
# Year 2011 - Best C: 10, Best MSE: 0.0907, Time: 20.12 seconds
# Year 2012 - Best C: 10, Best MSE: 0.0924, Time: 20.51 seconds
# Year 2013 - Best C: 100, Best MSE: 0.0983, Time: 17.72 seconds
# Year 2014 - Best C: 10, Best MSE: 0.0962, Time: 19.34 seconds
# Year 2015 - Best C: 10, Best MSE: 0.0929, Time: 18.68 seconds
# Year 2016 - Best C: 10, Best MSE: 0.1027, Time: 18.67 seconds
# Year 2017 - Best C: 100, Best MSE: 0.0937, Time: 14.81 seconds
# Year 2018 - Best C: 10, Best MSE: 0.101, Time: 17.29 seconds
# Year 2019 - Best C: 100, Best MSE: 0.1008, Time: 14.57 seconds
# Year 2020 - Best C: 100, Best MSE: 0.0897, Time: 13.31 seconds
# Year 2021 - Best C: 100, Best MSE: 0.0855, Time: 15.00 seconds
# Year 2022 - Best C: 100, Best MSE: 0.0965, Time: 14.24 seconds

# %%
############################################
# DECISION TREE CLASSIFICATION MODEL
############################################

model_name = 'DT_class_roll20_MSE'


# Predefined set of max_depth values for hyperparameter tuning
HP1 = [3, 5, 10, 15, 25, None] # max_depth

# Update the column name for storing Decision Tree regression predictions
df[model_name] = np.nan

# Ensure the new column is in the prediction_cols list
if model_name not in prediction_cols:
    prediction_cols.append(model_name)

start_modeling_year = df['year'].min() + 7

for year in range(start_modeling_year, df['year'].max() + 1):
    start_time = time.time()  # Timing each iteration
    
    train_start_year = max(year - rolling_window, df['year'].min())
    train_data = df[(df['year'] >= train_start_year) & (df['year'] < year)]
    
    tuning_data = train_data[train_data['year'] == year - 1]
    actual_train_data = train_data[train_data['year'] < year - 1]
    
    X_train = actual_train_data[X_col]
    y_train = actual_train_data['y']
    
    X_tune = tuning_data[X_col]
    y_tune = tuning_data['y']
    
    best_HP1 = None
    best_mse = float('inf')
    
    # Hyperparameter tuning for max_depth
    for hp1 in HP1:
        model = DecisionTreeClassifier(max_depth=hp1)
        model.fit(X_train, y_train)
        probabilities = model.predict_proba(X_tune)[:, 1]
        mse = mean_squared_error(y_tune, probabilities)  # Calculate MSE
        
        if mse < best_mse:  # Lower MSE is better
            best_mse = mse
            best_HP1 = hp1
    
    # Retrain on the entire training window with the best max_depth value
    model = DecisionTreeClassifier(max_depth=best_HP1)
    model.fit(X_train, y_train)
    
    # Predict for the next year
    next_year_data = df[df['year'] == year]
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
prediction_cols
# prediction_cols = ['logit_default','OLS_default','logit_roll6','DT_reg_roll']
# Out:
# ['ols_default',
#  'ridge_clas_exp_MSE',
#  'DT_clas_exp_MSE',
#  'ridge_clas_roll5_MSE',
#  'DT_class_roll5_MSE',
#  'ridge_clas_roll10_MSE',
#  'DT_class_roll10_MSE',
#  'ridge_clas_roll20_MSE',
#  'DT_class_roll20_MSE']

# %%
portfolio = df[['date', 'RET', 'ME', 'y'] + prediction_cols].copy()
portfolio['date'] = pd.to_datetime(portfolio['date'])

# drop rows with missing values
portfolio.dropna(inplace=True)

portfolio.head()
# Out:
#             date       RET          ME  y  ols_default  ridge_clas_exp_MSE  \
# 49083 1933-01-31  0.036765   31918.875  1     0.700424            0.995678
# 49084 1933-01-31  0.121849    7142.250  1     0.472653            0.481409
# 49085 1933-01-31  0.015625    1560.000  1     0.775651            0.999940
# 49086 1933-01-31 -0.084337    4275.000  0     0.050251            0.000015
# 49087 1933-01-31 -0.037500  447581.750  0     0.369477            0.318965
#
#        DT_clas_exp_MSE  ridge_clas_roll5_MSE  DT_class_roll5_MSE  \
# 49083         1.000000              0.993238            1.000000
# 49084         0.267922              0.464035            0.340836
# 49085         1.000000              0.999850            1.000000
# 49086         0.000000              0.000026            0.000000
# 49087         0.160714              0.329626            0.354545
#
#        ridge_clas_roll10_MSE  DT_class_roll10_MSE  ridge_clas_roll20_MSE  \
# 49083               0.994455             1.000000               0.994455
# 49084               0.478552             0.269823               0.478552
# 49085               0.999904             1.000000               0.999904
# 49086               0.000019             0.000000               0.000019
# 49087               0.314195             0.160714               0.314195
#
#        DT_class_roll20_MSE
# 49083             1.000000
# 49084             0.269823
# 49085             1.000000
# 49086             0.000000
# 49087             0.160714

# %%
portfolio.tail()
# Out:
#               date       RET            ME  y  ols_default  \
# 3627748 2022-07-31 -0.106939  3.731571e+06  0     0.626592
# 3627749 2022-07-31  0.020969  5.066263e+03  1     0.526688
# 3627750 2022-07-31  0.184785  1.280287e+06  1     0.799235
# 3627751 2022-07-31  0.108881  3.475711e+04  1     0.493767
# 3627752 2022-07-31  0.323765  9.311106e+08  1     0.717418
#
#          ridge_clas_exp_MSE  DT_clas_exp_MSE  ridge_clas_roll5_MSE  \
# 3627748            0.820784         0.771429              0.892252
# 3627749            0.663772         0.568068              0.838531
# 3627750            0.969509         0.990749              0.984135
# 3627751            0.609127         0.568068              0.787141
# 3627752            0.920358         0.968750              0.949727
#
#          DT_class_roll5_MSE  ridge_clas_roll10_MSE  DT_class_roll10_MSE  \
# 3627748            0.757556               0.902244             0.466019
# 3627749            0.757556               0.841806             0.131148
# 3627750            0.757556               0.985462             0.987890
# 3627751            0.757556               0.797412             0.131148
# 3627752            0.757556               0.955620             0.466019
#
#          ridge_clas_roll20_MSE  DT_class_roll20_MSE
# 3627748               0.837965             0.449787
# 3627749               0.751108             0.449787
# 3627750               0.976392             0.983327
# 3627751               0.694356             0.449787
# 3627752               0.925194             0.898927

# %%
# Initialize an empty DataFrame to store value-weighted returns for each model
vwreturns = pd.DataFrame(portfolio['date'].unique(), columns=['date'])  # Ensures all dates are included

for pred_col in prediction_cols:
    # Calculate deciles for this prediction
    decile_col = f'decile_{pred_col}'
    portfolio[decile_col] = portfolio.groupby(['date'])[pred_col].transform(lambda x: pd.qcut(x, 10, labels=False, duplicates='drop'))
    
    # Determine position based on deciles
    position_col = f'position_{pred_col}'
    portfolio[position_col] = np.where(portfolio[decile_col] == 9, 1, np.where(portfolio[decile_col] == 0, -1, 0))
    
    # Calculate the value-weighted return for this prediction
    vwret_col = f'vwreturn_{pred_col}'
    vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
    
    # Merge the temporary value-weighted returns with the main vwreturns DataFrame
    vwreturns = vwreturns.merge(vwreturns_temp, on='date', how='left')

# Ensure the 'date' column is the first column and is sorted
vwreturns = vwreturns.sort_values('date').reset_index(drop=True)
# Out:
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)
# /tmp/ipykernel_17/2999037948.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vwreturns_temp = portfolio.groupby('date').apply(lambda x: np.sum(x['RET'] * x['ME'] * x[position_col]) / np.sum(x['ME'])).reset_index(name=vwret_col)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_clas_exp_MSE  \
# 0 1933-01-31              0.020306                     0.021557
# 1 1933-02-28              0.011009                     0.009001
# 2 1933-03-31              0.028039                     0.028465
# 3 1933-04-30              0.075182                     0.050330
# 4 1933-05-31              0.024181                     0.019323
#
#    vwreturn_DT_clas_exp_MSE  vwreturn_ridge_clas_roll5_MSE  \
# 0                  0.005294                       0.021557
# 1                  0.092540                       0.008985
# 2                  0.026435                       0.028465
# 3                 -0.009979                       0.050056
# 4                 -0.246518                       0.019883
#
#    vwreturn_DT_class_roll5_MSE  vwreturn_ridge_clas_roll10_MSE  \
# 0                     0.006217                        0.021557
# 1                     0.065318                        0.009001
# 2                     0.026240                        0.028465
# 3                    -0.007120                        0.050330
# 4                    -0.246518                        0.019323
#
#    vwreturn_DT_class_roll10_MSE  vwreturn_ridge_clas_roll20_MSE  \
# 0                      0.005146                        0.021557
# 1                      0.095244                        0.009001
# 2                      0.023226                        0.028465
# 3                     -0.018039                        0.050330
# 4                     -0.246518                        0.019323
#
#    vwreturn_DT_class_roll20_MSE
# 0                      0.005146
# 1                      0.095244
# 2                      0.023226
# 3                     -0.018039
# 4                     -0.246518

# %% [markdown]
# ### Compare to market data

# %%
#market = pd.read_csv('FF3_clean.csv')
market = pd.read_csv('/kaggle/input/sign-prediction-datasets/FF3_clean.csv')

# %%
market.head()
# Out:
#          date  Mkt-RF   SMB   HML    RF
# 0  1926-07-31    2.96 -2.56 -2.43  0.22
# 1  1926-08-31    2.64 -1.17  3.82  0.25
# 2  1926-09-30    0.36 -1.40  0.13  0.23
# 3  1926-10-31   -3.24 -0.09  0.70  0.32
# 4  1926-11-30    2.53 -0.10 -0.51  0.31

# %%
# create a new 'Mkt' which is a sum of Mkt-RF and RF
market['Mkt'] = market['Mkt-RF'] + market['RF']

# divide all columns by 100 except 'date'
market.iloc[:, 1:] = market.iloc[:, 1:] / 100

#set the 'date' column to datetime format
market['date'] = pd.to_datetime(market['date'])

# merge the market data (only date and Mkt columns) with the vwreturns DataFrame
vwreturns = vwreturns.merge(market[['date', 'Mkt']], on='date', how='left')

# transform all columns (except 'date') to a log: log(x+1) and save the result as lvwreturns
lvwreturns = vwreturns.copy()
lvwreturns.iloc[:, 1:] = np.log(vwreturns.iloc[:, 1:] + 1)

# %%
vwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_clas_exp_MSE  \
# 0 1933-01-31              0.020306                     0.021557
# 1 1933-02-28              0.011009                     0.009001
# 2 1933-03-31              0.028039                     0.028465
# 3 1933-04-30              0.075182                     0.050330
# 4 1933-05-31              0.024181                     0.019323
#
#    vwreturn_DT_clas_exp_MSE  vwreturn_ridge_clas_roll5_MSE  \
# 0                  0.005294                       0.021557
# 1                  0.092540                       0.008985
# 2                  0.026435                       0.028465
# 3                 -0.009979                       0.050056
# 4                 -0.246518                       0.019883
#
#    vwreturn_DT_class_roll5_MSE  vwreturn_ridge_clas_roll10_MSE  \
# 0                     0.006217                        0.021557
# 1                     0.065318                        0.009001
# 2                     0.026240                        0.028465
# 3                    -0.007120                        0.050330
# 4                    -0.246518                        0.019323
#
#    vwreturn_DT_class_roll10_MSE  vwreturn_ridge_clas_roll20_MSE  \
# 0                      0.005146                        0.021557
# 1                      0.095244                        0.009001
# 2                      0.023226                        0.028465
# 3                     -0.018039                        0.050330
# 4                     -0.246518                        0.019323
#
#    vwreturn_DT_class_roll20_MSE     Mkt
# 0                      0.005146  0.0126
# 1                      0.095244 -0.1527
# 2                      0.023226  0.0333
# 3                     -0.018039  0.3895
# 4                     -0.246518  0.2147

# %%
lvwreturns.head()
# Out:
#         date  vwreturn_ols_default  vwreturn_ridge_clas_exp_MSE  \
# 0 1933-01-31              0.020103                     0.021328
# 1 1933-02-28              0.010949                     0.008961
# 2 1933-03-31              0.027653                     0.028067
# 3 1933-04-30              0.072490                     0.049104
# 4 1933-05-31              0.023893                     0.019139
#
#    vwreturn_DT_clas_exp_MSE  vwreturn_ridge_clas_roll5_MSE  \
# 0                  0.005280                       0.021328
# 1                  0.088505                       0.008945
# 2                  0.026092                       0.028067
# 3                 -0.010030                       0.048844
# 4                 -0.283051                       0.019688
#
#    vwreturn_DT_class_roll5_MSE  vwreturn_ridge_clas_roll10_MSE  \
# 0                     0.006198                        0.021328
# 1                     0.063273                        0.008961
# 2                     0.025901                        0.028067
# 3                    -0.007145                        0.049104
# 4                    -0.283051                        0.019139
#
#    vwreturn_DT_class_roll10_MSE  vwreturn_ridge_clas_roll20_MSE  \
# 0                      0.005133                        0.021328
# 1                      0.090977                        0.008961
# 2                      0.022960                        0.028067
# 3                     -0.018204                        0.049104
# 4                     -0.283051                        0.019139
#
#    vwreturn_DT_class_roll20_MSE       Mkt
# 0                      0.005133  0.012521
# 1                      0.090977 -0.165700
# 2                      0.022960  0.032758
# 3                     -0.018204  0.328944
# 4                     -0.283051  0.194497

# %%
lvwreturns.describe()
# Out:
#                                 date  vwreturn_ols_default  \
# count                           1074           1074.000000
# mean   1977-11-05 12:12:04.022346368              0.015480
# min              1933-01-31 00:00:00             -0.019337
# 25%              1955-06-07 12:00:00              0.010207
# 50%              1977-11-15 00:00:00              0.013988
# 75%              2000-03-23 06:00:00              0.018582
# max              2022-07-31 00:00:00              0.086511
# std                              NaN              0.008332
#
#        vwreturn_ridge_clas_exp_MSE  vwreturn_DT_clas_exp_MSE  \
# count                  1074.000000               1074.000000
# mean                      0.010901                  0.012606
# min                      -0.020949                 -0.283051
# 25%                       0.004928                  0.003254
# 50%                       0.010250                  0.007472
# 75%                       0.014832                  0.017071
# max                       0.080615                  0.193999
# std                       0.008244                  0.020918
#
#        vwreturn_ridge_clas_roll5_MSE  vwreturn_DT_class_roll5_MSE  \
# count                    1074.000000                  1074.000000
# mean                        0.011816                     0.011275
# min                        -0.020949                    -0.283051
# 25%                         0.006952                     0.002774
# 50%                         0.010935                     0.007722
# 75%                         0.015351                     0.018238
# max                         0.081136                     0.187124
# std                         0.007797                     0.024628
#
#        vwreturn_ridge_clas_roll10_MSE  vwreturn_DT_class_roll10_MSE  \
# count                     1074.000000                   1074.000000
# mean                         0.011211                      0.012072
# min                         -0.020949                     -0.283051
# 25%                          0.006235                      0.002962
# 50%                          0.010582                      0.007589
# 75%                          0.014781                      0.017542
# max                          0.080905                      0.193999
# std                          0.007640                      0.023912
#
#        vwreturn_ridge_clas_roll20_MSE  vwreturn_DT_class_roll20_MSE  \
# count                     1074.000000                   1074.000000
# mean                         0.010808                      0.012610
# min                         -0.020949                     -0.283051
# 25%                          0.005225                      0.003107
# 50%                          0.010022                      0.007395
# 75%                          0.014518                      0.017291
# max                          0.080598                      0.193999
# std                          0.008176                      0.021080
#
#                Mkt
# count  1074.000000
# mean      0.008968
# min      -0.272203
# 25%      -0.017248
# 50%       0.013064
# 75%       0.038162
# max       0.328944
# std       0.048186

# %%
## plot histograms of the value-weighted returns for each model and the market in lvwreturns
#plt.figure(figsize=(12, round(len(prediction_cols)/2) * 5 ))
#
#for i, pred_col in enumerate(prediction_cols):
#    plt.subplot(len(prediction_cols)/2 +1, 2, i+1)
#    plt.hist(lvwreturns[f'vwreturn_{pred_col}'], bins=50, color='skyblue', edgecolor='black')
#    plt.title(f'Value-Weighted Return - {pred_col}')
#    plt.xlabel('Value-Weighted Return')
#    plt.ylabel('Frequency')
#    # calculate mean, skewness and kurtosis and add their values to the plot as a text, aligning to the top right corner
#    mean = lvwreturns[f'vwreturn_{pred_col}'].mean()
#    skewness = lvwreturns[f'vwreturn_{pred_col}'].skew()
#    kurtosis = lvwreturns[f'vwreturn_{pred_col}'].kurtosis()
#
#    plt.text(0.95, 0.95, f'Mean: {mean:.4f}\nSkewness: {skewness:.4f}\nKurtosis: {kurtosis:.4f}', ha='right', va='top', transform=plt.gca().transAxes)
#
#
#
#plt.subplot(round(len(prediction_cols)/2) +1, 2, len(prediction_cols)+1)
#plt.title('Value-Weighted Return - Market')
#plt.xlabel('Value-Weighted Return')
#plt.ylabel('Frequency')
#plt.hist(lvwreturns['Mkt'], bins=50, color='skyblue', edgecolor='black')
#mean = lvwreturns['Mkt'].mean()
#skewness = lvwreturns['Mkt'].skew()
#kurtosis = lvwreturns['Mkt'].kurtosis()
#plt.text(0.95, 0.95, f'Mean: {mean:.4f}\nSkewness: {skewness:.4f}\nKurtosis: {kurtosis:.4f}', ha='right', va='top', transform=plt.gca().transAxes)
#
#plt.tight_layout()
#plt.show()
#

# %%
## plot cumulative sums of the value-weighted log returns
#plt.figure(figsize=(12, 6))
#plt.plot(lvwreturns['date'], lvwreturns.iloc[:, 1:].cumsum())
#plt.title('Cumulative Value-Weighted Log Returns')
#plt.xlabel('Date')
#plt.ylabel('Cumulative Value-Weighted Log Returns')
#plt.legend(prediction_cols + ['Market'])
#plt.show()

# %%
# save the lvwreturns and portfolio DataFrame to a parquet file into 'outputs' folder

# for reproducibility and visualization purposes
lvwreturns.to_parquet('lvwreturnsC.parquet')
portfolio.to_parquet('portfolioC.parquet')

# save vwreturns DataFrame to a .dta file into 'outputs' folder
#vwreturns.to_stata('outputs/vwreturns.dta') # for backtasting in R - we need normal returns, not log returns
